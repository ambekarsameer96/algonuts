# %% [markdown]
# #Terms of Use
# By using this colab to download the brain dataset (i.e., data including fMRI, images, labels), you agree to the following terms:
#
# 1. You will use the Datasets only for non-commercial research and educational purposes.
# 2. You will NOT distribute the Datasets or any parts thereof.
# 3. Massachusetts Institute of Technology make no representations or warranties regarding the datasets, including but not limited to warranties of non-infringement or fitness for a particular purpose.
# 4. You accept full responsibility for your use of the datasets and shall defend and indemnify Massachusetts Institute of Technology and International Business Machines Corporation, including its employees, officers and agents, against any and all claims arising from your use of the datasets, including but not limited to your use of any copyrighted images that you may create from the datasets.
# 5. You will treat people appearing in this data with respect and dignity.
# 6. This data comes with no warranty or guarantee of any kind, and you accept full liability.

# %% [markdown]
# # Predicting fMRI responses from Algonauts2021 dataset
#
# **Goal:** Here we show how to prepare submission for Algonauts 2021 challenge using AlexNet as an example.
#
# This notebook is organized as follows:
#
# 1. Loading fMRI responses to videos and visualizing in glass brain using nilearn.
# 2. Feedforward the videos from stimulus set to the AlexNet model pretrained on Imagenet dataset to extract AlexNet activations from different layers and apply PCA for dimensionality reduction.
# 3.   Train a linear regression to predict fMRI responses from AlexNet activations.
# 4.   Evaluate the model by comparing the correlation between predicted and recorded fMRI responses on validation set.
# 5. Generate predicted fMRI responses to test videos for all subjects all ROIs
# 6. Preparing submission files for codalab

# %%
#@title Installations
# %%capture

# !pip install nilearn
# !pip install decord

# %%
#@title Imports
import glob
import numpy as np
import urllib
import torch
import cv2
import argparse
import time
import random
import matplotlib.pyplot as plt
import nibabel as nib
import pickle
from nilearn import plotting
from tqdm import tqdm
from torchvision import transforms as trn
import os
from PIL import Image
from sklearn.preprocessing import StandardScaler
from torch.autograd import Variable as V
from sklearn.decomposition import PCA, IncrementalPCA
import torch.nn as nn
import torch.utils.model_zoo as model_zoo
import torch.nn.functional as F
from nilearn import datasets
from nilearn import surface
from decord import VideoReader
from decord import cpu
# Out:
# /usr/local/lib/python3.7/dist-packages/nilearn/datasets/__init__.py:89: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %% [markdown]
# Get the dropbox link to download dataset by filling this [google form](https://forms.gle/qq9uqqu6SwN8ytxQ9).

# %%
#@title Enter the download link and run the cell
download_link = '' #@param {type:"string"}
os.environ["download_link"] = download_link
# !echo $download_link 
# !wget -O participants_data.zip -c $download_link  
# !unzip participants_data.zip
# !wget -O example.nii -c https://github.com/Neural-Dynamics-of-Visual-Cognition-FUB/Algonauts2021_devkit/raw/main/example.nii
# !wget -c https://raw.githubusercontent.com/Neural-Dynamics-of-Visual-Cognition-FUB/Algonauts2021_devkit/main/class_names_ImageNet.txt
# Out:
# https://www.dropbox.com/s/agxyxntrbwko7t1/participants_data.zip?dl=0
# --2021-06-21 15:12:40--  https://www.dropbox.com/s/agxyxntrbwko7t1/participants_data.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6022:18::a27d:4212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/agxyxntrbwko7t1/participants_data.zip [following]
# --2021-06-21 15:12:41--  https://www.dropbox.com/s/raw/agxyxntrbwko7t1/participants_data.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com/cd/0/inline/BQ1W51U-cJOVqaEvtrziNNzrgY-BLmZONvKRhu3Dt86XBb2etF-LIgS2zTpuN8iIhRHA6gAvpACgL4SGS01CSq5aetxhjJAIjSjZXUJJreOySU80pgXXz1i3cQOTfA_8U4v_z9uafqUSJxjzBBN_Usq4/file# [following]
# --2021-06-21 15:12:41--  https://uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com/cd/0/inline/BQ1W51U-cJOVqaEvtrziNNzrgY-BLmZONvKRhu3Dt86XBb2etF-LIgS2zTpuN8iIhRHA6gAvpACgL4SGS01CSq5aetxhjJAIjSjZXUJJreOySU80pgXXz1i3cQOTfA_8U4v_z9uafqUSJxjzBBN_Usq4/file
# Resolving uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com (uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6022:15::a27d:420f
# Connecting to uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com (uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BQ2VxsWjQHMX_oA23wfossbV483djbCGtkSbPJ3c_YwWuDZhVuB_S5YWdNqMstB0p7XW8jzd8FUTgcNUZz-Fsp-Cg-JKDhROeOvlinLVAtI4of3VZleb-iVIv26cNOwWqjhB-AGskxy6c4FgjrXodMLFwx5iciSV57A_-EDVXxob8L1jIn2eiu4Pg1DsffxkuBd23foR9DvSHoaqMgUJdlk7trNQEN9eNO0D2qh4-2Z-tqpQNHjUT6BDTxatimmxJj3DUEzqNWc1P7mcERfLD4hvXGKSYajuTlWCg6TRpVWyO8rF1asQOAMPzzAzeDazO8PR4gcuv2V9VmAd3V68CjKuWJ8q2NInJ1uaI8AtzuZIBCWleN755O7izdJSlhLpPtM/file [following]
# --2021-06-21 15:12:41--  https://uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com/cd/0/inline2/BQ2VxsWjQHMX_oA23wfossbV483djbCGtkSbPJ3c_YwWuDZhVuB_S5YWdNqMstB0p7XW8jzd8FUTgcNUZz-Fsp-Cg-JKDhROeOvlinLVAtI4of3VZleb-iVIv26cNOwWqjhB-AGskxy6c4FgjrXodMLFwx5iciSV57A_-EDVXxob8L1jIn2eiu4Pg1DsffxkuBd23foR9DvSHoaqMgUJdlk7trNQEN9eNO0D2qh4-2Z-tqpQNHjUT6BDTxatimmxJj3DUEzqNWc1P7mcERfLD4hvXGKSYajuTlWCg6TRpVWyO8rF1asQOAMPzzAzeDazO8PR4gcuv2V9VmAd3V68CjKuWJ8q2NInJ1uaI8AtzuZIBCWleN755O7izdJSlhLpPtM/file
# Reusing existing connection to uc3bc253d085cb313e5b70749655.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4591675883 (4.3G) [application/zip]
# Saving to: ‘participants_data.zip’
#
# participants_data.z 100%[===================>]   4.28G  45.4MB/s    in 84s
#
# 2021-06-21 15:14:06 (52.3 MB/s) - ‘participants_data.zip’ saved [4591675883/4591675883]
#
# Archive:  participants_data.zip
#    creating: AlgonautsVideos268_All_30fpsmax/
#   inflating: AlgonautsVideos268_All_30fpsmax/0001_0-0-1-6-7-2-8-0-17500167280.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0002_0-0-4-3146384004.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0003_0-0-8-1-2-4-0-0-3500812400.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0004_0-1-2-9-1-9-9-5-2401291995.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0005_0-1-7-8-3-6-4-8-4401783648.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0006_0-1-9-9-8-6-5-9-4701998659.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0007_0-2-3-14056753023.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0008_0-2-9-6-5-7-2-3-16002965723_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0009_0-3-5-4-1-3-6-2-8603541362.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0010_0-3-6-10842732036.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0011_0-3-6-2-3-3-4-4-8103623344.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0012_0-5-3-7-6-2-8-4-24105376284.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0013_0-5-3-8-6-8-2-6-4805386826.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0014_0-5-6-8272016056_edit.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0015_0-6-1-9759583061.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0016_0-6-6-1-5-8-2-5-14806615825.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0017_0-7-3-5856076073.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0018_0-7-7-9-8-1-7-4-24407798174.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0019_0-7-9-9-7-7-1-5-4307997715.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0020_0-8-0-0-3-9-3-9-7108003939.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0021_0-8-0-8-6-5-4-5-4708086545.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0022_0-8-7-7-9-6-5-5-6508779655.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0023_0-8-8-7346836088.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0024_0-9-3-5943645093.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0025_0-9-5-1-8-2-6-6-4009518266.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0026_0-9-9-8-0-5-8-5-4909980585.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0027_03chvdioZYI_85.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0028_0P6FNr_6XWo_35.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0029_1-0-7-2-7-1-8-6-2810727186.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0030_1-1-5-6-1-6-5-2-2811561652.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0031_1-1-8-8-3-2-8-3-13711883283.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0032_1-2-0-9-0-9-1-6-3812090916_61.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0033_1-2-5-1-2-7-6-2-2512512762.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0034_1-2-5-3344278125.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0035_1-2-6-3176369126.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0036_1-2-6-9-6-8-2-1-22212696821.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0037_1-3-9-9-9-6-4-3-3213999643.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0038_1-4-3-5-8-6-2-5-3114358625.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0039_1-4-4-4086629144.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0040_1-4-8-8-7-8-7-5-3914887875_56.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0041_1-5-0-0-4-9-7-8-2915004978_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0042_1-5-8-9-2-4-5-4-7815892454.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0043_1-6-0-2796094160.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0044_1-6-0-7-7-6-4-6-7816077646.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0045_1-6-8-0-7-6-7-4-3816807674.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0046_1-6-8-5795643168.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0047_1-7-1-8-6-3-6-2-3417186362.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0048_1-7-2-5-5-0-7-5-25617255075.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0049_1-7-4-5-3-8-3-6-3017453836.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0050_1-8-5-7127344185.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0051_1-8-7-1-1-9-6-6-5418711966.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0052_1-9-3-0-9-4-6-4-4719309464.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0053_1-9-3-2-8-0-1-3-3919328013.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0054_1-9-3-9-3-8-2-2-23719393822.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0055_1-9-6-7-5-1-9-8-3119675198.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0056_2-0-0-3614591200.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0057_2-0-9-8159444209.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0058_2-4-3-5345273243.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0059_2-5-7-6889839257.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0060_2-6-5-12330534265.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0061_2-9-5-4309863295.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0062_2EMSeADyrrQ_35.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0063_2Ng8UYBFhbU_91.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0064_2Tm26dLw29A_69.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0065_2aG9AaxuGSU_148.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0066_2cCnDHUV0W8_35.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0067_2h1Mj2ymyj8_121.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0068_3-0-4-4343808304.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0069_3-0-5-3-4-3-5-2-4730534352.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0070_3-3-6-8-2-7-6-6-3533682766.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0071_3-4-9-8-4-7-4-8-4434984748.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0072_3-5-0-4261181350.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0073_3-5-8-9-9-5-9-8-4335899598.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0074_3-6-5-3-3-4-4-5-23036533445.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0075_3-7-0-7-1-5-3-0-4937071530.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0076_3-7-3-13269577373.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0077_3-7-3-7-1-7-0-1-2537371701.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0078_3-7-5-4-7-7-8-9-8037547789.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0079_3-7-5-6-6-4-1-7-3437566417.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0080_3-9-0-6-4-2-6-6-3339064266.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0081_4-0-6-7-6-1-4-5-4540676145.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0082_4-2-5-6-5-3-6-5-16342565365.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0083_4-3-3-1-0-6-4-0-8743310640.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0084_4-3-4-8736778434.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0085_4-3-5-6-0-8-0-8-5543560808.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0086_4-3-5-9059723435.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0087_4-3-7-4396869437.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0088_4-3-7-4889733437.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0089_4-3-8-2-7-7-4-3-9043827743.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0090_4-4-7-5-2-9-5-4-4744752954.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0091_4-5-0-1-4-3-5-1-15645014351.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0092_4-5-7-1-7-9-4-4-5945717944.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0093_4-5-7-5265004457.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0094_4-5-9-2-3-0-7-9-15245923079.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0095_4-6-1-9-8-5-2-4-25546198524.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0096_4-7-1-1-2-8-3-0-25247112830.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0097_4-7-9-4959184479.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0098_4-7-9-5224564479.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0099_4-7-9-5897473479.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0100_4-7-9-7-6-5-8-0-2647976580.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0101_4-8-4-5-2-8-6-4-12748452864.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0102_4-8-9-2-5-7-3-1-3848925731.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0103_4-9-0-4-8-4-8-7-3949048487.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0104_4_mAU3U33fU_224.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0105_5-0-2-9044555502.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0106_5-0-6-7-7-5-7-6-14950677576_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0107_5-2-4-5-8-0-7-9-4752458079.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0108_5-3-4-9966677534.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0109_5-3-7-1-9-2-1-2-3453719212.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0110_5-4-0-2405298540.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0111_5-4-2-6-1-5-0-7-5654261507.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0112_5-4-2-6-3-7-5-4-7854263754.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0113_5-4-3-5-0-8-5-4-13654350854_22.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0114_5-4-5-2-2-4-8-5-8454522485.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0115_5-4-5-4-1-8-6-5-8254541865_29.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0116_5-6-5-5-1-6-7-5-23256551675.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0117_5-6-6-3042970566.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0118_5-6-7-7-6-0-9-9-3756776099.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0119_5-7-0-7-8-9-1-3-4257078913.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0120_5-7-5-3760841575.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0121_5-7-6-1-2-1-4-3-17357612143.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0122_5-7-6-9-5-4-8-2-5457695482.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0123_5-9-0-1-9-6-9-0-5259019690.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0124_5-9-1-5611850591.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0125_5-9-4-9166960594.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0126_5-9-7-5-7-9-9-8-2859757998.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0127_5541389947.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0128_5948238182.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0129_5pZ8Z7icwxE_276.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0130_6-0-7-6496350607.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0131_6-0-9-5-1-4-3-4-3260951434.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0132_6-1-0-8-4-3-3-3-2461084333.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0133_6-2-2-4-7-1-0-3-6562247103.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0134_6-3-7-7169142637.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0135_6-4-0-3-0-0-4-4-22064030044.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0136_6-4-4-8-8-6-2-5-8164488625.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0137_6-5-9-3859686659.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0138_6-6-1-2641881661.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0139_6-6-6-7-7-0-2-9-6866677029_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0140_6-6-8-7-5-4-8-7-8066875487_24.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0141_6-7-0-1-4-8-8-0-9267014880.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0142_6-8-1-3-0-3-6-5-11768130365.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0143_6-8-5-2652653685.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0144_6-gEVb8H_fk_649.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0145_7-0-7-8-4-7-5-8-14570784758.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0146_7-1-5-1-5-3-3-7-7171515337.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0147_7-1-6-7637947716.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0148_7-1-8-0-6-6-5-3-2471806653.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0149_7-1-8-7-4-8-0-6-2471874806.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0150_7-2-3-4-0-4-6-7-3872340467.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0151_7-2-5-2-4-9-1-1-3572524911.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0152_7-3-2-8-5-5-7-0-2773285570_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0153_7-3-3-3-1-1-7-8-5973331178.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0154_7-3-3-8-1-7-0-5-5773381705.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0155_7-3-3-9823355733.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0156_7-3-8-8-3-3-3-0-6873883330_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0157_7-4-3-9701238743.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0158_7-5-4-8-3-8-3-6-25975483836.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0159_7-6-3-1-6-7-9-2-7876316792_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0160_7-7-0-2652639770.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0161_7-7-2-8-9-8-8-7-3077289887.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0162_7-7-4-0-8-2-3-2-21577408232.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0163_7-8-4-11617872784.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0164_7-8-4-4-0-9-0-9-3778440909.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0165_7-8-5-4189422785.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0166_7-9-1-9-1-3-1-5-5879191315.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0167_7-9-2-5805821792.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0168_7-9-2-6804993792.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0169_7-9-4-13012552794.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0170_75FvTr78rVo_238.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0171_8-1-0-2784666810.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0172_8-3-1-7-3-3-2-6-3583173326_54.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0173_8-5-6-13941149856.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0174_8-6-1-3575610861.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0175_8-6-7-3034848867.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0176_8-7-1-7072478871.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0177_8-7-5-4-7-4-9-9-6687547499.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0178_8-7-8-2585165878.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0179_8-7-8-4802252878.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0180_8-8-1-8014192881.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0181_8-9-0-3381035890.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0182_8-9-7-3822181897.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0183_8709292427.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0184_8bbL5ZTo8J4_322.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0185_9-0-0-5-1-3-8-3-14090051383.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0186_9-0-3-0-6-1-0-2-16890306102.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0187_9-1-4-8-0-4-3-2-4391480432.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0188_9-1-6-3-6-9-9-7-4791636997.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0189_9-3-3-3-4-8-5-2-3193334852.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0190_9-3-6-5336600936.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0191_9-3-7-9-4-7-7-2-15393794772.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0192_9-4-9-8061428949.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0193_9-5-5-4087587955.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0194_9-6-0-4-3-8-6-5-17196043865.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0195_9-8-1-5713854981.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0196_9-8-8-3-3-0-9-9-3998833099.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0197_C_T0k4u1WVA_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0198_HK42zQTEb1g_232.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0199_KrKLuEmzcBM_26.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0200_L0axrvyv6co_40.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0201_LnIGqQ6uIls_28.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0202_OeYnX9NwB1k_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0203_VJkSUu4f83Q_50.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0204_a7hMxItSNjQ_99.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0205_aahG-A2T4Ro_192.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0206_attsYxVO2pM_122.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0207_bing-www_dailymotion_com_video_x68vowz_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0208_bing-www_facebook_com_sewwhatalicia_videos_1148889631878967__612.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0209_bing-www_wikihow_com_Button-a-Suit_82.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0210_dwxnKkVw4Z0_143.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0211_flickr-0-0-0-0-3-1-1-4-16000003114_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0212_flickr-0-0-0-1-9-7-6-6-5700019766_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0213_flickr-0-0-2-0-8-2-2-8-2400208228_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0214_flickr-0-0-2-6-5-7-8-4-10900265784_27.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0215_flickr-0-0-3-7-1-7-7-4-10300371774_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0216_flickr-0-0-3-8-0-2-1-4-7000380214_32.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0217_flickr-0-0-3-8-6-7-6-9-18500386769_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0218_flickr-0-0-3-9-1-2-6-1-2600391261_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0219_flickr-0-0-5-0-5-7-9-5-4200505795_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0220_flickr-0-0-5-7-8-8-8-6-4800578886_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0221_flickr-0-0-6-6-3-9-4-5-4900663945_62.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0222_flickr-0-0-6-8-8-6-4-9-18100688649_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0223_flickr-0-0-8-4-5-7-3-6-3000845736_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0224_flickr-0-0-8-6-3-9-7-8-4700863978_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0225_flickr-0-0-9-0-4-3-5-7-14400904357_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0226_flickr-0-1-1-4-7-8-8-0-2801147880_27.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0227_flickr-0-1-6-1-8-9-0-0-5601618900_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0228_flickr-0-1-6-4-5-9-7-4-12301645974_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0229_flickr-0-1-6-5-6-1-9-9-4701656199_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0230_flickr-0-1-7-9-2-7-7-4-16001792774_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0231_flickr-0-2-0-6-5-9-0-9-2402065909_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0232_flickr-0-2-3-12544471023_3_edit.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0233_flickr-0-2-4-5-1-7-7-2-15002451772_20.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0234_flickr-0-2-5-2-4-5-4-3-2402524543_23.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0235_flickr-0-2-5-6-0-1-4-0-2602560140_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0236_flickr-0-2-8-1-1-8-8-3-5502811883_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0237_flickr-0-2-8-2-2-8-3-3-16002822833_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0238_flickr-0-2-8-4-3-6-5-9-4702843659_25.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0239_flickr-0-2-8-6-7-4-1-6-2502867416_28.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0240_flickr-0-2-9-8-3-1-1-8-14302983118_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0241_flickr-0-2-9-9-4-2-5-2-6002994252_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0242_flickr-0-3-0-7-9-7-3-7-15303079737_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0243_flickr-0-3-1-9-1-9-8-3-16003191983_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0244_flickr-0-3-4-0-6-1-0-2-4203406102_32.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0245_flickr-0-3-5-7-4-0-5-2-7303574052_27.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0246_flickr-0-3-5-8-0-4-5-4-5603580454_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0247_flickr-0-3-6-1-2-6-1-2-8603612612_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0248_flickr-0-3-6-8-9-9-8-3-5603689983_73.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0249_flickr-0-3-7-0-8-2-3-6-4803708236_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0250_flickr-0-3-7-4-5-4-2-7-3103745427_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0251_flickr-0-3-7-7-5-2-7-4-4103775274_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0252_flickr-0-3-8-9-3-9-2-3-21303893923_17.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0253_flickr-0-4-0-4-6-6-0-7-5504046607_55.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0254_flickr-0-4-0-8-8-1-7-2-14904088172_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0255_flickr-0-4-1-8-7-1-9-3-5404187193_18.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0256_flickr-0-4-2-3-4-8-2-7-2704234827_48.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0257_flickr-0-4-2-5-3-4-5-6-2804253456_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0258_flickr-0-4-2-8-4-5-1-8-7404284518_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0259_flickr-0-4-2-9-9-2-1-2-5704299212_23.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0260_flickr-0-4-3-3-2-9-6-0-6004332960_22.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0261_flickr-0-4-3-8586022043_54.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0262_flickr-0-4-6-7-5-5-6-8-4104675568_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0263_flickr-0-4-7-4-3-5-2-3-16004743523_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0264_flickr-0-4-9-8-1-8-2-0-2604981820_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0265_flickr-0-5-1-4-4-8-1-6-14805144816_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0266_flickr-0-5-1-8-3-4-4-6-2405183446_28.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0267_flickr-0-5-2-0-1-7-0-1-2605201701_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0268_flickr-0-5-3-3-8-8-4-5-2805338845_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0269_flickr-0-5-3-6-8-4-1-5-6605368415_74.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0270_flickr-0-5-4-1-6-2-4-5-25805416245_171.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0271_flickr-0-5-5-2-9-5-2-0-4605529520_17.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0272_flickr-0-5-6-9-8-9-1-3-3105698913_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0273_flickr-0-5-7-2-5-7-0-9-4505725709_54.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0274_flickr-0-5-8-4899813058_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0275_flickr-0-5-8-8-4-5-7-1-3605884571_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0276_flickr-0-5-9-1-7-6-0-8-4605917608_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0277_flickr-0-5-9-2-3-9-0-6-2905923906_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0278_flickr-0-5-9-4073111059_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0279_flickr-0-5-9-9-5-4-2-9-8005995429_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0280_flickr-0-6-0-2-0-2-0-7-7106020207_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0281_flickr-0-6-0-2-7-3-3-7-2606027337_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0282_flickr-0-6-0-4-8-3-3-3-18406048333_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0283_flickr-0-6-2-7-5-3-8-1-2406275381_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0284_flickr-0-6-3-9-5-7-1-3-2406395713_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0285_flickr-0-6-6-8-2-5-3-7-4606682537_18.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0286_flickr-0-6-8-3-0-7-4-5-7006830745_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0287_flickr-0-6-9-0-8-5-4-6-4106908546_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0288_flickr-0-6-9-2-6-4-2-4-7206926424_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0289_flickr-0-6-9-4-4-0-1-4-2406944014_44.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0290_flickr-0-7-0-1-1-7-8-1-4007011781_26.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0291_flickr-0-7-5-8-6-6-9-6-16307586696_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0292_flickr-0-7-6-1-6-9-6-4-18707616964_18.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0293_flickr-0-8-0-5-8-5-6-3-8608058563_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0294_flickr-0-8-0-9-2-1-8-6-4408092186_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0295_flickr-0-8-1-3-1-2-7-5-20908131275_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0296_flickr-0-8-2-9-9-5-7-5-2508299575_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0297_flickr-0-8-3-1-3-9-9-3-5608313993_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0298_flickr-0-8-6-3-0-1-7-9-2708630179_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0299_flickr-0-8-6-7264391086_18.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0300_flickr-0-8-7-2-7-6-5-9-4808727659_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0301_flickr-0-8-8-7-2-4-7-2-5808872472_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0302_flickr-0-8-8-9-8-5-8-9-5808898589_41.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0303_flickr-0-8-9-4-7-3-8-1-25008947381_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0304_flickr-0-8-9-6-3-0-0-2-4108963002_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0305_flickr-0-9-0-2-4-0-8-5-2709024085_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0306_flickr-0-9-0-4-0-9-6-9-3109040969_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0307_flickr-0-9-3-0-3-3-6-8-2409303368_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0308_flickr-0-9-5-2-0-1-3-0-2609520130_68.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0309_flickr-0-9-5-2-6-8-5-8-3309526858_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0310_flickr-0-9-6-6-7-2-0-5-5909667205_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0311_flickr-0-9-7-4-9-5-4-8-3109749548_27.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0312_flickr-0-9-7-5-3-6-5-6-13909753656_75.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0313_flickr-0-9-7-5-8-5-1-2-7909758512_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0314_flickr-0-9-9-0-5-6-3-4-8609905634_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0315_flickr-0-9-9-3-9-2-4-8-7409939248_27.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0316_flickr-0-9-9-9-1-2-4-8-2909991248_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0317_flickr-0-9-9-9-4-8-9-4-3509994894_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0318_flickr-1-0-0-6-5-9-6-0-8310065960_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0319_flickr-1-0-3-6-5-6-5-1-4210365651_58.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0320_flickr-1-0-6-4-2-3-3-2-5710642332_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0321_flickr-1-0-7-5-8-2-0-5-9110758205_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0322_flickr-1-0-7-9-0-2-7-3-5310790273_65.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0323_flickr-1-1-3-3-0-6-5-4-5611330654_24.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0324_flickr-1-1-4-7-0-2-2-7-14611470227_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0325_flickr-1-1-4-9-2-7-0-5-17311492705_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0326_flickr-1-1-5-8-1-6-0-2-3511581602_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0327_flickr-1-1-8-0-0-2-8-3-5311800283_51.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0328_flickr-1-2-5-8694421125_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0329_flickr-1-2-5-9-6-3-3-4-11912596334_16.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0330_flickr-1-2-6-6021305126_23.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0331_flickr-1-2-6-9-2-7-6-4-5312692764_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0332_flickr-1-2-9-4-2-2-9-8-7712942298_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0333_flickr-1-3-1-6-4-6-6-3-3813164663_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0334_flickr-1-3-1-7-4-9-0-5-4613174905_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0335_flickr-1-3-3-9-7-7-8-7-4613397787_41.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0336_flickr-1-3-9-6679895139_93.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0337_flickr-1-4-0-2-9-9-3-6-6114029936_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0338_flickr-1-4-0-7-8-1-9-3-6114078193_31.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0339_flickr-1-4-1-6-7-5-8-9-5414167589_43.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0340_flickr-1-4-2-5-6-9-3-9-5214256939_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0341_flickr-1-4-3-6815990143_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0342_flickr-1-4-6-8-8-2-1-1-4314688211_37.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0343_flickr-1-4-6-9-7-5-3-3-3414697533_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0344_flickr-1-4-7-9-7-0-4-4-11814797044_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0345_flickr-1-5-2-5-5-2-4-9-5115255249_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0346_flickr-1-5-2-7-8-9-2-5-5515278925_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0347_flickr-1-5-2-9-9-5-0-6-3115299506_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0348_flickr-1-5-3-8-7-3-3-9-2715387339_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0349_flickr-1-5-4-4-2-2-8-9-3315442289_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0350_flickr-1-5-4-6-6-9-4-2-2815466942_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0351_flickr-1-5-4-8-5-6-8-7-5415485687_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0352_flickr-1-5-6-8-7-5-1-6-18715687516_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0353_flickr-1-5-6-9-2-2-5-4-7815692254_29.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0354_flickr-1-5-6-9-7-0-2-3-4915697023_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0355_flickr-1-5-7-7-5-1-1-1-2415775111_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0356_flickr-1-5-9-9-6-4-8-5-23815996485_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0357_flickr-1-6-1-2-3-2-2-6-4316123226_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0358_flickr-1-6-1-8-6-6-4-5-8316186645_17.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0359_flickr-1-6-2-3-0-0-5-1-5016230051_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0360_flickr-1-6-2-3-9-1-3-3-7016239133_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0361_flickr-1-6-5-4-8-1-5-8-3816548158_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0362_flickr-1-6-8-5-1-5-0-6-5016851506_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0363_flickr-1-7-1-1-6-6-4-3-6517116643_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0364_flickr-1-7-3-5-9-5-8-4-9617359584_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0365_flickr-1-7-4-9-9-0-5-7-2917499057_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0366_flickr-1-7-6-8-9-2-5-6-3117689256_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0367_flickr-1-7-6-9-4-6-4-5-5617694645_23.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0368_flickr-1-7-7-4-9-3-9-0-3617749390_25.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0369_flickr-1-7-8-3-7-4-8-7-2817837487_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0370_flickr-1-7-9-4-4-9-4-4-7617944944_22.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0371_flickr-1-7-9-5-9-9-4-8-22417959948_18.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0372_flickr-1-8-0-2-3-9-5-9-4918023959_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0373_flickr-1-8-7-4-5-1-0-5-4518745105_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0374_flickr-1-9-1-9-7-1-5-5-17219197155_2_edit.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0375_flickr-1-9-5-5-9-4-1-2-6119559412_17.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0376_flickr-1-9-6-8-8-5-8-2-15619688582_87.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0377_flickr-1-9-9-7-1-3-5-0-5419971350_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0378_flickr-2-0-2-8568328202_159.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0379_flickr-2-0-5-10028691205_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0380_flickr-2-0-5-8313532205_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0381_flickr-2-0-6-0-5-8-8-4-20420605884_112.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0382_flickr-2-0-8-2-2-5-4-6-22620822546_96.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0383_flickr-2-0-8-3-2-4-0-4-15920832404_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0384_flickr-2-0-9-4-2-3-5-8-8320942358_28.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0385_flickr-2-1-0-9-1-4-7-1-16621091471_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0386_flickr-2-1-2-2-8-3-9-1-15721228391_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0387_flickr-2-1-4-1-7-8-4-4-3321417844_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0388_flickr-2-1-5-9-7-4-5-7-15121597457_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0389_flickr-2-1-6-5-5-0-2-7-4021655027_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0390_flickr-2-1-7-9-2-7-6-1-16621792761_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0391_flickr-2-1-8-9-8-3-7-6-2621898376_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0392_flickr-2-2-3-3-5-1-1-5-16622335115_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0393_flickr-2-2-4-0-5-4-2-0-8322405420_55.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0394_flickr-2-2-5-9-2-6-8-7-5222592687_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0395_flickr-2-2-6-9-9-3-0-8-3422699308_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0396_flickr-2-2-9-7975460229_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0397_flickr-2-3-2-4-2-2-1-8-5323242218_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0398_flickr-2-3-3-6-7-8-6-6-15123367866_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0399_flickr-2-3-5-4-6-5-5-2-6923546552_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0400_flickr-2-3-7-2-1-7-0-1-16623721701_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0401_flickr-2-3-7-2-4-7-9-5-5823724795_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0402_flickr-2-3-7-9-4-9-7-6-2923794976_16.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0403_flickr-2-3-8-2-3-9-0-2-15823823902_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0404_flickr-2-4-0-2-2-7-7-1-2424022771_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0405_flickr-2-4-1-5-4-5-5-4-4724154554_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0406_flickr-2-4-2-2-5-5-1-5-16624225515_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0407_flickr-2-4-2-4-4-5-5-1-6524244551_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0408_flickr-2-4-2-6-7-9-3-0-4524267930_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0409_flickr-2-4-8-2436811248_77.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0410_flickr-2-4-8-7-5-8-8-0-2424875880_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0411_flickr-2-4-9-3-6-1-9-4-14024936194_35.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0412_flickr-2-4-9-8-1-0-6-8-3224981068_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0413_flickr-2-4-9-8-7-4-7-9-24224987479_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0414_flickr-2-5-4-4-3-9-5-9-8625443959_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0415_flickr-2-5-7-0-8-8-8-8-6225708888_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0416_flickr-2-5-9-0-7-1-0-7-6225907107_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0417_flickr-2-5-9-4-2-0-8-5-4425942085_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0418_flickr-2-6-6-4784306266_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0419_flickr-2-6-6-6-6-4-6-1-19826666461_117.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0420_flickr-2-6-7-0-3-1-7-5-24326703175_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0421_flickr-2-6-7-1-1-7-8-3-14526711783_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0422_flickr-2-6-7-4396444267_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0423_flickr-2-7-0-5-3-0-2-1-3127053021_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0424_flickr-2-7-1-1-4-5-2-6-4027114526_68.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0425_flickr-2-7-4-4-6-6-4-5-3427446645_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0426_flickr-2-7-4-8-7-0-5-5-20127487055_45.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0427_flickr-2-7-6-1-5-5-9-1-9127615591_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0428_flickr-2-7-7-2-1-6-8-8-5327721688_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0429_flickr-2-7-8-2-3-7-0-7-7127823707_44.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0430_flickr-2-8-0-0-8-7-9-3-23628008793_8.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0431_flickr-2-8-1-7183499281_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0432_flickr-2-8-5-8-1-6-8-0-4128581680_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0433_flickr-2-8-8-7-2-7-0-1-4828872701_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0434_flickr-2-9-0-7-9-9-3-3-16529079933_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0435_flickr-2-9-0-9-0-5-4-2-3229090542_33.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0436_flickr-2-9-0-9-7-4-0-3-20129097403_59.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0437_flickr-2-9-3-0-2-4-6-0-3529302460_36.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0438_flickr-2-9-5-0-5-0-4-6-5329505046_38.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0439_flickr-2-9-5-4347204295_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0440_flickr-2-9-8-3-2-1-2-0-9129832120_20.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0441_flickr-2-9-9-5-9-0-8-4-7929959084_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0442_flickr-2-9-9-8-3-0-1-7-4329983017_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0443_flickr-3-0-0-8-9-8-3-5-16230089835_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0444_flickr-3-0-1-3006399301_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0445_flickr-3-0-2-0-1-8-7-4-2530201874_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0446_flickr-3-0-2-2-2-9-5-2-18130222952_49.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0447_flickr-3-0-2-8-4-3-3-1-3630284331_26.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0448_flickr-3-0-3-4-4-0-5-9-2430344059_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0449_flickr-3-0-3-4844566303_17.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0450_flickr-3-0-4-4997186304_22.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0451_flickr-3-0-8-9-1-7-0-3-5530891703_51.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0452_flickr-3-1-0-1-7-3-6-2-7831017362_46.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0453_flickr-3-1-1-1-2-7-9-5-3931112795_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0454_flickr-3-1-6-1-3-5-5-2-15131613552_40.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0455_flickr-3-1-6-5690390316_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0456_flickr-3-1-6-8-0-3-4-3-2531680343_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0457_flickr-3-1-7-9-4-5-7-6-23631794576_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0458_flickr-3-1-8-0-9-1-9-5-2731809195_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0459_flickr-3-1-8-7-5-2-2-4-19231875224_17.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0460_flickr-3-1-9-3-3-8-8-1-5331933881_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0461_flickr-3-2-1-3-8-8-5-0-4132138850_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0462_flickr-3-2-5-5905609325_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0463_flickr-3-2-5-6-3-4-7-3-13532563473_69.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0464_flickr-3-2-6-1-3-2-1-4-11532613214_32.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0465_flickr-3-2-7-8-5-7-8-0-4532785780_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0466_flickr-3-2-8-2-1-7-3-6-26332821736_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0467_flickr-3-2-9-8272259329_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0468_flickr-3-3-1-5-3-1-6-2-4133153162_54.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0469_flickr-3-3-3-4-7-1-3-6-2733347136_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0470_flickr-3-3-6-0-8-7-1-3-2933608713_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0471_flickr-3-3-7-3-7-9-2-7-2633737927_23.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0472_flickr-3-3-9-0-0-5-9-8-4333900598_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0473_flickr-3-3-9-5-2-7-5-7-3833952757_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0474_flickr-3-4-4-10578385344_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0475_flickr-3-4-4-6-6-4-5-6-4534466456_16.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0476_flickr-3-4-5-8-0-0-0-8-2934580008_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0477_flickr-3-4-7-3-3-3-3-9-6034733339_21.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0478_flickr-3-5-4-0-1-6-6-0-16435401660_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0479_flickr-3-5-4-8-7-5-4-5-6735487545_33.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0480_flickr-3-5-7-9-3-0-7-2-16035793072_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0481_flickr-3-5-8-7-6-6-7-1-8035876671_24.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0482_flickr-3-6-1-5-3-4-7-1-4736153471_25.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0483_flickr-3-6-2-8-2-8-1-0-2436282810_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0484_flickr-3-6-3-5-3-2-4-9-2536353249_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0485_flickr-3-6-5-3-6-4-5-4-3436536454_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0486_flickr-3-6-6-0-6-4-2-9-5636606429_16.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0487_flickr-3-6-7-6-1-2-9-0-16436761290_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0488_flickr-3-6-7-9-2-2-8-9-25236792289_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0489_flickr-3-7-0-3-0-2-0-2-4837030202_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0490_flickr-3-7-0-9-9-8-0-5-2937099805_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0491_flickr-3-7-3-4-7-6-3-9-16437347639_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0492_flickr-3-7-4-6-0-0-6-1-2837460061_26.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0493_flickr-3-7-5-0-5-7-1-0-24837505710_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0494_flickr-3-7-5-3-3-0-5-9-4037533059_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0495_flickr-3-7-7-4-2-5-7-6-14437742576_59.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0496_flickr-3-7-7-4-3-9-9-6-6337743996_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0497_flickr-3-7-8-4-8-3-4-9-3637848349_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0498_flickr-3-8-1-6-3-8-6-8-5438163868_20.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0499_flickr-3-8-4-0-9-5-4-6-2938409546_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0500_flickr-3-8-5-1-6-3-6-9-16538516369_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0501_flickr-3-8-5-7-5-9-3-9-16038575939_43_edit.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0502_flickr-3-8-5-9-3-8-0-6-4938593806_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0503_flickr-3-8-6-7-0-4-9-6-2838670496_41.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0504_flickr-3-8-7-3-0-7-3-4-3838730734_35.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0505_flickr-3-8-7-3-9-3-4-2-3138739342_35.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0506_flickr-3-8-8-6-3-7-5-7-9538863757_48.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0507_flickr-3-9-0-9-6-4-0-2-25839096402_143.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0508_flickr-3-9-1-6-8-5-2-5-12039168525_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0509_flickr-3-9-3-3-6-0-2-5-16839336025_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0510_flickr-3-9-3-5-6-4-7-1-3139356471_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0511_flickr-3-9-4-0-1-1-7-3-9939401173_11.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0512_flickr-3-9-5-3668296395_18.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0513_flickr-3-9-6-7367078396_14.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0514_flickr-3-9-7-8-1-6-2-9-22639781629_108.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0515_flickr-4-0-0-0-4-8-9-6-2440004896_51.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0516_flickr-4-0-0-2-8-6-9-6-3140028696_6-converted_edit.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0517_flickr-4-0-1-6-2-7-4-6-7640162746_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0518_flickr-4-0-1-8-0-2-5-3-3640180253_53.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/0519_flickr-4-0-1-9-9-8-9-0-3940199890_39.mp4
# ...
#   inflating: AlgonautsVideos268_All_30fpsmax/1027_flickr-0-8-7-7-9-6-5-5-6508779655_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1028_flickr-1-3-3-4-2-0-4-4-8713342044_16.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1029_flickr-1-4-8-9-3-2-7-3-5214893273_51.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1030_flickr-1-6-3-4-7-1-2-2-7416347122_13.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1031_flickr-1-6-4-4-5-3-5-3-8016445353_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1032_flickr-1-8-2-7-3-9-4-1-3418273941_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1033_flickr-1-8-9-0-8-8-3-5-3118908835_9.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1034_flickr-1-9-1-2-0-6-5-7-3419120657_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1035_flickr-1-9-2-9-1-2-7-9-2819291279_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1036_flickr-2-0-1-5-3-8-4-8-2620153848_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1037_flickr-2-3-2-2-6-8-3-4-4323226834_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1038_flickr-2-4-1-6-4-7-6-4-25824164764_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1039_flickr-2-6-9-4-0-2-5-5-23726940255_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1040_flickr-2-8-2-9-2-9-1-2-5528292912_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1041_flickr-3-0-8-3-3-8-7-0-21830833870_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1042_flickr-3-1-6-4273893316_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1043_flickr-3-3-5-7-3-2-0-1-25133573201_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1044_flickr-3-6-4-1-2-5-7-1-14436412571_16.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1045_flickr-3-9-0-1-2-9-0-4-5139012904_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1046_flickr-3-9-9-6-5-2-2-2-2839965222_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1047_flickr-4-0-9-6-4-2-5-5-3740964255_17.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1048_flickr-4-1-6-8-4-4-3-7-9241684437_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1049_flickr-4-2-3-3-7-5-1-1-5742337511_79.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1050_flickr-4-3-8-2-7-2-5-3-24043827253_16.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1051_flickr-4-4-3-4-8-8-0-7-5544348807_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1052_flickr-4-4-4-6-0-1-7-6-2844460176_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1053_flickr-4-4-6-0-7-0-7-4-18344607074_27.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1054_flickr-4-5-1-3-9-3-3-5-4045139335_26.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1055_flickr-4-6-1-1-4-8-4-5-5646114845_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1056_flickr-4-6-2-0-0-8-2-0-7346200820_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1057_flickr-4-6-3-6-6-6-1-8-5346366618_25.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1058_flickr-4-6-5-3-9-2-9-2-8446539292_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1059_flickr-4-7-6-4-2-0-1-9-3147642019_44.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1060_flickr-5-1-1-3-0-6-1-1-5751130611_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1061_flickr-5-3-2-3-9-9-4-9-6553239949_6.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1062_flickr-5-5-5-2-7-6-7-5-6555527675_63.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1063_flickr-5-6-5-9-6-6-9-8-4056596698_27.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1064_flickr-5-8-9-4-3-4-9-1-21858943491_22.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1065_flickr-5-9-5-4-5-3-9-6-23759545396_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1066_flickr-6-0-4-10248141604_15.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1067_flickr-6-2-3-8-5-3-2-8-6262385328_12.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1068_flickr-6-3-0-2-0-5-4-6-6163020546_34.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1069_flickr-6-3-4-6-5-3-2-6-8663465326_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1070_flickr-6-4-3-4-1-8-0-7-3564341807_2.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1071_flickr-6-4-5-9-0-9-2-5-11864590925_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1072_flickr-6-5-7-1-6-0-5-3-4465716053_21.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1073_flickr-6-6-4-8-3-7-6-7-14766483767_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1074_flickr-6-6-6-3-3-6-2-9-3366633629_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1075_flickr-7-0-6-11866890706_21.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1076_flickr-7-0-6-9-5-0-6-9-4870695069_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1077_flickr-7-0-8-7-2-3-0-0-4670872300_21.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1078_flickr-7-1-2-0-7-9-8-2-15371207982_57.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1079_flickr-7-2-5-4-8-0-1-2-3572548012_36.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1080_flickr-7-4-6-0-0-0-8-5-6074600085_35.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1081_flickr-7-4-6-7-0-5-2-2-2874670522_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1082_flickr-7-5-9-2-7-9-5-7-5075927957_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1083_flickr-7-7-3-9603898773_34.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1084_flickr-7-9-1-9-7-8-4-1-5979197841_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1085_flickr-7-9-4-0-2-6-4-0-6079402640_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1086_flickr-7-9-4-4-0-1-3-1-4879440131_23.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1087_flickr-8-3-0-8-9-8-8-1-6683089881_3.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1088_flickr-8-5-6-1-4-4-5-2-4385614452_26.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1089_flickr-8-7-6-1-4-7-8-2-4287614782_43.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1090_flickr-8-7-8-9-2-2-1-8-17787892218_4.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1091_flickr-8-9-1-1-1-8-9-7-6289111897_52.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1092_flickr-8-9-2-5207705892_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1093_flickr-9-1-1-6-2-7-4-0-8691162740_7.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1094_flickr-9-2-6-2-1-2-9-5-6292621295_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1095_flickr-9-2-7-0-8-0-7-0-4292708070_55.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1096_flickr-9-7-8-9-1-2-7-1-3797891271_19.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1097_flickr-9-7-9-2-2-7-7-2-25797922772_10.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1098_flickr-9-8-3-6-5-8-3-2-3798365832_1.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1099_flickr-9-9-3-9-3-3-1-0-6799393310_48.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1100_flickr-jena76-4855129978_5.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1101_flickr-scrambldmeggs-3606262338_21.mp4
#   inflating: AlgonautsVideos268_All_30fpsmax/1102_meta_R-5602303_250.mp4
#    creating: participants_data_v2021/
#    creating: participants_data_v2021/full_track/
#    creating: participants_data_v2021/full_track/sub01/
#   inflating: participants_data_v2021/full_track/sub01/WB.pkl
#    creating: participants_data_v2021/full_track/sub02/
#   inflating: participants_data_v2021/full_track/sub02/WB.pkl
#    creating: participants_data_v2021/full_track/sub03/
#   inflating: participants_data_v2021/full_track/sub03/WB.pkl
#    creating: participants_data_v2021/full_track/sub04/
#   inflating: participants_data_v2021/full_track/sub04/WB.pkl
#    creating: participants_data_v2021/full_track/sub05/
#   inflating: participants_data_v2021/full_track/sub05/WB.pkl
#    creating: participants_data_v2021/full_track/sub06/
#   inflating: participants_data_v2021/full_track/sub06/WB.pkl
#    creating: participants_data_v2021/full_track/sub07/
#   inflating: participants_data_v2021/full_track/sub07/WB.pkl
#    creating: participants_data_v2021/full_track/sub08/
#   inflating: participants_data_v2021/full_track/sub08/WB.pkl
#    creating: participants_data_v2021/full_track/sub09/
#   inflating: participants_data_v2021/full_track/sub09/WB.pkl
#    creating: participants_data_v2021/full_track/sub10/
#   inflating: participants_data_v2021/full_track/sub10/WB.pkl
#    creating: participants_data_v2021/mini_track/
#    creating: participants_data_v2021/mini_track/sub01/
#   inflating: participants_data_v2021/mini_track/sub01/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub01/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub01/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub01/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub01/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub01/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub01/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub01/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub01/V4.pkl
#    creating: participants_data_v2021/mini_track/sub02/
#   inflating: participants_data_v2021/mini_track/sub02/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub02/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub02/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub02/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub02/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub02/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub02/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub02/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub02/V4.pkl
#    creating: participants_data_v2021/mini_track/sub03/
#   inflating: participants_data_v2021/mini_track/sub03/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub03/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub03/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub03/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub03/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub03/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub03/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub03/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub03/V4.pkl
#    creating: participants_data_v2021/mini_track/sub04/
#   inflating: participants_data_v2021/mini_track/sub04/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub04/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub04/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub04/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub04/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub04/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub04/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub04/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub04/V4.pkl
#    creating: participants_data_v2021/mini_track/sub05/
#   inflating: participants_data_v2021/mini_track/sub05/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub05/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub05/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub05/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub05/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub05/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub05/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub05/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub05/V4.pkl
#    creating: participants_data_v2021/mini_track/sub06/
#   inflating: participants_data_v2021/mini_track/sub06/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub06/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub06/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub06/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub06/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub06/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub06/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub06/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub06/V4.pkl
#    creating: participants_data_v2021/mini_track/sub07/
#   inflating: participants_data_v2021/mini_track/sub07/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub07/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub07/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub07/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub07/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub07/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub07/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub07/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub07/V4.pkl
#    creating: participants_data_v2021/mini_track/sub08/
#   inflating: participants_data_v2021/mini_track/sub08/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub08/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub08/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub08/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub08/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub08/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub08/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub08/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub08/V4.pkl
#    creating: participants_data_v2021/mini_track/sub09/
#   inflating: participants_data_v2021/mini_track/sub09/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub09/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub09/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub09/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub09/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub09/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub09/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub09/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub09/V4.pkl
#    creating: participants_data_v2021/mini_track/sub10/
#   inflating: participants_data_v2021/mini_track/sub10/EBA.pkl
#   inflating: participants_data_v2021/mini_track/sub10/FFA.pkl
#   inflating: participants_data_v2021/mini_track/sub10/LOC.pkl
#   inflating: participants_data_v2021/mini_track/sub10/PPA.pkl
#   inflating: participants_data_v2021/mini_track/sub10/STS.pkl
#   inflating: participants_data_v2021/mini_track/sub10/V1.pkl
#   inflating: participants_data_v2021/mini_track/sub10/V2.pkl
#   inflating: participants_data_v2021/mini_track/sub10/V3.pkl
#   inflating: participants_data_v2021/mini_track/sub10/V4.pkl
# --2021-06-21 15:16:10--  https://github.com/Neural-Dynamics-of-Visual-Cognition-FUB/Algonauts2021_devkit/raw/main/example.nii
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Neural-Dynamics-of-Visual-Cognition-FUB/Algonauts2021_devkit/main/example.nii [following]
# --2021-06-21 15:16:10--  https://raw.githubusercontent.com/Neural-Dynamics-of-Visual-Cognition-FUB/Algonauts2021_devkit/main/example.nii
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2021-06-21 15:16:10--  https://raw.githubusercontent.com/Neural-Dynamics-of-Visual-Cognition-FUB/Algonauts2021_devkit/main/class_names_ImageNet.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %% [markdown]
# #fMRI Data
#
# The Algonauts dataset provides human brain responses to a set of 1,102 3-s long video clips of everyday events. The brain responses are measured with functional magnetic resonance imaging (fMRI). fMRI is a widely used brain imaging technique with high spatial resolution that measures blood flow changes associated with neural responses.
#
# The training set consists of 1,000 video clips and the associated brain responses. The brain responses are provided here in two tracks corresponding to two independent tracks in the Algonauts challenge.
#
# In the **full track**, brain responses provided are from selected voxels across the whole brain showing reliable responses to videos. The figure below shows the reliability values of different voxels in the brain.

# %% [markdown]
# ![average_subject_reliability.png](data:image/png;base64,...)

# %% [markdown]
# In the **mini track**, brain responses provided are from a set of specific regions of interest (ROIs) known to play a key role in visual perception. These ROIs start in early and mid-level visual cortex (V1, V2, V3, and V4) and extend into higher-level cortex that responds preferentially to all objects or particular categories (Body- EBA; Face - FFA, STS; Object - LOC; Scene - PPA). In the figure below we show the masks of the above mentioned ROIs for an example subject.

# %% [markdown]
# ![ROIs.png](data:image/png;base64,...)

# %% [markdown]
# #Loading fMRI data
# The trainig dataset contains 1,000 3-second videos + fMRI human brain data of 10 subjects in response to viewing videos from this set.
#
# The ROI data is provided for 9 ROIs of the visual brain (V1, V2, V3, V4, LOC, EBA, FFA, STS, PPA) in a Pickle file (e.g. V1.pkl) that contains a num_videos x num_repetitions x num_voxels matrix. For each ROI, we selected voxels that showed significant split-half reliability.
#
# The whole brain data is provided for selected voxels across the whole brain showing reliable responses to videos in a Pickle file (e.g. WB.pkl) that contains a num_videos x num_repetitions x num_voxels matrix.
#
# In this section, we demonstrate how to load fMRI data for a given ROI.

# %%
#@title Utility functions for data loading
def save_dict(di_, filename_):
    with open(filename_, 'wb') as f:
        pickle.dump(di_, f)

def load_dict(filename_):
    with open(filename_, 'rb') as f:
        u = pickle._Unpickler(f)
        u.encoding = 'latin1'
        ret_di = u.load()
    return ret_di

def visualize_activity(vid_id,sub):
  fmri_dir = './participants_data_v2021' 
  track = "full_track"
  results_dir = '/content/'
  track_dir = os.path.join(fmri_dir, track) 
  sub_fmri_dir = os.path.join(track_dir, sub)
  fmri_train_all,voxel_mask = get_fmri(sub_fmri_dir,"WB") 
  visual_mask_3D = np.zeros((78,93,71))
  visual_mask_3D[voxel_mask==1]= fmri_train_all[vid_id,:]
  brain_mask = '/content/example.nii'
  nii_save_path =  os.path.join(results_dir, 'vid_activity.nii')
  saveasnii(brain_mask,nii_save_path,visual_mask_3D)
  plotting.plot_glass_brain(nii_save_path,
                          title='fMRI response',plot_abs=False,
                          display_mode='lyr',colorbar=True)

def get_activations(activations_dir, layer_name):
    """This function loads neural network features/activations (preprocessed using PCA) into a
    numpy array according to a given layer.
    Parameters
    ----------
    activations_dir : str
        Path to PCA processed Neural Network features
    layer_name : str
        which layer of the neural network to load,
    Returns
    -------
    train_activations : np.array
        matrix of dimensions #train_vids x #pca_components
        containing activations of train videos
    test_activations : np.array
        matrix of dimensions #test_vids x #pca_components
        containing activations of test videos
    """

    train_file = os.path.join(activations_dir,"train_" + layer_name + ".npy")
    test_file = os.path.join(activations_dir,"test_" + layer_name + ".npy")
    train_activations = np.load(train_file)
    test_activations = np.load(test_file)
    scaler = StandardScaler()
    train_activations = scaler.fit_transform(train_activations)
    test_activations = scaler.fit_transform(test_activations)

    return train_activations, test_activations

def get_fmri(fmri_dir, ROI):
    """This function loads fMRI data into a numpy array for to a given ROI.
    Parameters
    ----------
    fmri_dir : str
        path to fMRI data.
    ROI : str
        name of ROI.
    Returns
    -------
    np.array
        matrix of dimensions #train_vids x #repetitions x #voxels
        containing fMRI responses to train videos of a given ROI
    """


    # Loading ROI data
    ROI_file = os.path.join(fmri_dir, ROI + ".pkl")
    ROI_data = load_dict(ROI_file)

    # averaging ROI data across repetitions
    ROI_data_train = np.mean(ROI_data["train"], axis = 1)
    if ROI == "WB":
        voxel_mask = ROI_data['voxel_mask']
        return ROI_data_train, voxel_mask

    return ROI_data_train

def saveasnii(brain_mask,nii_save_path,nii_data):
    img = nib.load(brain_mask)
    nii_img = nib.Nifti1Image(nii_data, img.affine, img.header)
    nib.save(nii_img, nii_save_path)

# %%
#@title Loading fMRI data and inspecting dimensions
sub = 'sub04'  #@param ["sub01","sub02","sub03","sub04","sub05","sub06","sub07","sub08","sub09","sub10"]  

ROI = 'LOC'  #@param ["WB", "V1", "V2","V3", "V4", "LOC", "EBA", "FFA","STS", "PPA"]

######## fMRI data loader wrapper code ###################################
fmri_dir = '/content/participants_data_v2021' 
if ROI == "WB":
    track = "full_track"
else:
    track = "mini_track"
results_dir = '/content/'
track_dir = os.path.join(fmri_dir, track) 
sub_fmri_dir = os.path.join(track_dir, sub)
if track == "full_track":
    fmri_train_all,voxel_mask = get_fmri(sub_fmri_dir,ROI)
else:
    fmri_train_all = get_fmri(sub_fmri_dir,ROI)

######## fMRI data loader wrapper code ###################################


f, ax = plt.subplots(figsize=(12, 5))
ax.set(xlabel="Voxel", ylabel="Stimulus")
heatmap = ax.imshow(fmri_train_all, aspect="auto",cmap='jet',vmin=-1,vmax=1)
f.colorbar(heatmap, shrink=.5, label="Response amplitude (Z)")
f.tight_layout()

# %% [markdown]
# The above matrix shows each individual voxel's (columns) response to 1000 videos (rows). To find out more details about how the fMRI data were preprocessed please click [here](http://algonauts.csail.mit.edu/brainmappingandanalysis.html).

# %% [markdown]
# Visualize a given video (with id from 0-999) and its corresponding brain activity

# %%
#@title Visualize video
vid_id = 266 #@param {type: "integer"}
video_dir = '/content/AlgonautsVideos268_All_30fpsmax'

########### Video display code #################################################
video_list = glob.glob(video_dir + '/*.mp4')
video_list.sort()

#visualize_brain_activity(video_dir,fmri_train_all,vid_id)
from IPython.display import HTML
from base64 import b64encode

mp4 = open(video_list[vid_id],'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
    <source src="%s" type="video/mp4">
</video>
""" % data_url)
########### Video display code #################################################
# Out:
# <video width=400 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
#@title Visualize corresponding brain response
visualize_activity(vid_id,sub)

# %% [markdown]
# The values in the fMRI response above correspond to beta values from 5s to 9s after stimulus onset calculated using an Finite Impulse Response (FIR) model. The beta values were averaged across time and z-scored across videos.

# %% [markdown]
# # Vision Model definition (AlexNet)
#
# Run the next cell to define the architecture of the model using pytorch.

# %%
#@title AlexNet
__all__ = ['AlexNet', 'alexnet']


model_urls = {
    'alexnet': 'https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth',
}


class AlexNet(nn.Module):

    def __init__(self, num_classes=1000):
        super(AlexNet, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            )
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            )
        self.conv3 = nn.Sequential(
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            )
        self.conv4 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            )
        self.conv5 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            )
        self.fc6 = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            )
        self.fc7 =nn.Sequential(
            nn.Dropout(),
            nn.Linear(4096, 4096),
            )
        self.fc8 = nn.Sequential(
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
            )

    def forward(self, x):
        out1 = self.conv1(x)
        out2 = self.conv2(out1)
        out3 = self.conv3(out2)
        out4 = self.conv4(out3)
        out5 = self.conv5(out4)

        out5_reshaped = out5.view(out5.size(0), 256 * 6 * 6)
        out6= self.fc6(out5_reshaped)
        out7= self.fc7(out6)
        out8 = self.fc8(out7)
        return out1, out2, out3,out4, out5, out6,out7,out8


def alexnet(pretrained=False, **kwargs):
    r"""AlexNet model architecture from the
    `"One weird trick..." <https://arxiv.org/abs/1404.5997>`_ paper.
    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
    """
    model = AlexNet(**kwargs)
    if pretrained:
        model.load_state_dict(model_zoo.load_url(model_urls['alexnet']))
    return model

# %% [markdown]
# #Feature Extraction
# Run the next cell to extract Alexnet activations on the videos from the stimulus set. We will use these later to train a regression for predicting fMRI responses.

# %%
#@title Functions for loading videos and extracting features
seed = 42
# Torch RNG
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
# Python RNG
np.random.seed(seed)
random.seed(seed)

def load_alexnet(model_checkpoints):
    """This function initializes an Alexnet and load
    its weights from a pretrained model
    ----------
    model_checkpoints : str
        model checkpoints location.
    Returns
    -------
    model
        pytorch model of alexnet
    """


    model = alexnet()
    model_file = model_checkpoints
    checkpoint = torch.load(model_file, map_location=lambda storage, loc: storage)
    model_dict =["conv1.0.weight", "conv1.0.bias", "conv2.0.weight", "conv2.0.bias", "conv3.0.weight", "conv3.0.bias", "conv4.0.weight", "conv4.0.bias", "conv5.0.weight", "conv5.0.bias", "fc6.1.weight", "fc6.1.bias", "fc7.1.weight", "fc7.1.bias", "fc8.1.weight", "fc8.1.bias"]
    state_dict={}
    i=0
    for k,v in checkpoint.items():
        state_dict[model_dict[i]] =  v
        i+=1

    model.load_state_dict(state_dict)
    if torch.cuda.is_available():
        model.cuda()
    model.eval()
    return model

def print_alexnet_predictions(output):
    with open('class_names_ImageNet.txt') as labels:
        classes = [i.strip() for i in labels.readlines()]

    # sort the probability vector in descending order
    sorted, indices = torch.sort(output, descending=True)
    percentage = F.softmax(output, dim=1)[0] * 100.0
    # obtain the first 5 classes (with the highest probability) the input belongs to
    results = [(classes[i], percentage[i].item()) for i in indices[0][:5]]
    for i in range(5):
        print('{}: {:.4f}%'.format(results[i][0], results[i][1]))
    

def sample_video_from_mp4(file, num_frames=16):
    """This function takes a mp4 video file as input and returns
    a list of uniformly sampled frames (PIL Image).
    Parameters
    ----------
    file : str
        path to mp4 video file
    num_frames : int
        how many frames to select using uniform frame sampling.
    Returns
    -------
    images: list of PIL Images
    num_frames: int
        number of frames extracted
    """
    images = list()
    vr = VideoReader(file, ctx=cpu(0))
    total_frames = len(vr)
    indices = np.linspace(0,total_frames-1,num_frames,dtype=np.int)
    for seg_ind in indices:
        images.append(Image.fromarray(vr[seg_ind].asnumpy()))

    return images,num_frames

def get_activations_and_save(model, video_list, activations_dir):
    """This function generates Alexnet features and save them in a specified directory.
    Parameters
    ----------
    model :
        pytorch model : alexnet.
    video_list : list
        the list contains path to all videos.
    activations_dir : str
        save path for extracted features.
    """

    resize_normalize = trn.Compose([
            trn.Resize((224,224)),
            trn.ToTensor(),
            trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

    for video_file in tqdm(video_list):
        vid,num_frames = sample_video_from_mp4(video_file)
        video_file_name = os.path.split(video_file)[-1].split(".")[0]
        activations = []
        for frame,img in enumerate(vid):
            input_img = V(resize_normalize(img).unsqueeze(0))
            if torch.cuda.is_available():
                input_img=input_img.cuda()
            x = model.forward(input_img)
            for i,feat in enumerate(x):
                if frame==0:
                    if i==7:
                        print("\nTop-5 Predictions for the video id: ", video_file_name)
                        print_alexnet_predictions(feat)
                    activations.append(feat.data.cpu().numpy().ravel())
                else:
                    activations[i] =  activations[i] + feat.data.cpu().numpy().ravel()
        for layer in range(len(activations)):
            save_path = os.path.join(activations_dir, video_file_name+"_"+"layer" + "_" + str(layer+1) + ".npy")
            avg_layer_activation = activations[layer]/float(num_frames)
            np.save(save_path,avg_layer_activation)

def do_PCA_and_save(activations_dir, save_dir):
    """This function preprocesses Neural Network features using PCA and save the results
    in  a specified directory
.
    Parameters
    ----------
    activations_dir : str
        save path for extracted features.
    save_dir : str
        save path for extracted PCA features.
    """

    layers = ['layer_1','layer_2','layer_3','layer_4','layer_5','layer_6','layer_7','layer_8']
    n_components = 100
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    for layer in tqdm(layers):
        activations_file_list = glob.glob(activations_dir +'/*'+layer+'.npy')
        activations_file_list.sort()
        feature_dim = np.load(activations_file_list[0])
        x = np.zeros((len(activations_file_list),feature_dim.shape[0]))
        for i,activation_file in enumerate(activations_file_list):
            temp = np.load(activation_file)
            x[i,:] = temp
        x_train = x[:1000,:]
        x_test = x[1000:,:]

        start_time = time.time()
        x_test = StandardScaler().fit_transform(x_test)
        x_train = StandardScaler().fit_transform(x_train)
        ipca = PCA(n_components=n_components,random_state=seed)
        ipca.fit(x_train)

        x_train = ipca.transform(x_train)
        x_test = ipca.transform(x_test)
        train_save_path = os.path.join(save_dir,"train_"+layer)
        test_save_path = os.path.join(save_dir,"test_"+layer)
        np.save(train_save_path,x_train)
        np.save(test_save_path,x_test)

# %%
video_dir = '/content/AlgonautsVideos268_All_30fpsmax'
video_list = glob.glob(video_dir + '/*.mp4')
video_list.sort()
print('Total Number of Videos: ', len(video_list))
save_dir = "/content/activations_alexnet"
# load Alexnet
# Download pretrained Alexnet from:
# https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth
# and save in the current directory
checkpoint_path = "/content/alexnet.pth"
if not os.path.exists(checkpoint_path):
    url = "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth"
    urllib.request.urlretrieve(url, "/content/alexnet.pth")
model = load_alexnet(checkpoint_path)

# get and save activations

activations_dir = os.path.join(save_dir)
if not os.path.exists(activations_dir):
    os.makedirs(activations_dir)
print("-------------Saving activations ----------------------------")
get_activations_and_save(model, video_list, activations_dir)
# Out:
# Total Number of Videos:  1102
#   0%|          | 0/1102 [00:00<?, ?it/s]
# -------------Saving activations ----------------------------
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#   0%|          | 1/1102 [00:00<12:12,  1.50it/s]
# Top-5 Predictions for the video id:  0001_0-0-1-6-7-2-8-0-17500167280
# red-breasted merganser, Mergus serrator: 47.7813%
# American coot, marsh hen, mud hen, water hen, Fulica americana: 31.1670%
# oystercatcher, oyster catcher: 4.4099%
# drake: 3.4130%
# dowitcher: 1.9694%
#   0%|          | 2/1102 [00:00<09:19,  1.97it/s]
# Top-5 Predictions for the video id:  0002_0-0-4-3146384004
# Bouvier des Flandres, Bouviers des Flandres: 28.6873%
# Scottish deerhound, deerhound: 9.3555%
# standard schnauzer: 6.3326%
# bulletproof vest: 5.2905%
# Irish wolfhound: 3.4212%
#
# Top-5 Predictions for the video id:  0003_0-0-8-1-2-4-0-0-3500812400
# croquet ball: 65.1707%
# golf ball: 8.7599%
# soccer ball: 3.3364%
# Bouvier des Flandres, Bouviers des Flandres: 2.7174%
# parachute, chute: 1.4735%
#   0%|          | 4/1102 [00:01<05:50,  3.13it/s]
# Top-5 Predictions for the video id:  0004_0-1-2-9-1-9-9-5-2401291995
# snowmobile: 44.3371%
# bobsled, bobsleigh, bob: 23.6392%
# dogsled, dog sled, dog sleigh: 19.1860%
# ski: 5.0738%
# swing: 1.1241%
#
# Top-5 Predictions for the video id:  0005_0-1-7-8-3-6-4-8-4401783648
# toyshop: 13.8475%
# bobsled, bobsleigh, bob: 8.1229%
# unicycle, monocycle: 5.9295%
# barbershop: 5.1377%
# volleyball: 3.8439%
#   1%|          | 7/1102 [00:01<03:31,  5.17it/s]
# Top-5 Predictions for the video id:  0006_0-1-9-9-8-6-5-9-4701998659
# space bar: 50.3253%
# crossword puzzle, crossword: 5.1862%
# grocery store, grocery, food market, market: 4.6133%
# library: 4.4329%
# balance beam, beam: 3.9810%
#
# Top-5 Predictions for the video id:  0007_0-2-3-14056753023
# restaurant, eating house, eating place, eatery: 81.0067%
# fire screen, fireguard: 1.4924%
# cello, violoncello: 0.9864%
# academic gown, academic robe, judge's robe: 0.8578%
# palace: 0.7574%
#   1%|          | 9/1102 [00:01<02:51,  6.37it/s]
# Top-5 Predictions for the video id:  0008_0-2-9-6-5-7-2-3-16002965723_1
# laptop, laptop computer: 8.9172%
# desk: 8.2000%
# perfume, essence: 6.2538%
# carton: 3.1992%
# face powder: 3.1583%
#
# Top-5 Predictions for the video id:  0009_0-3-5-4-1-3-6-2-8603541362
# plastic bag: 7.3394%
# triceratops: 6.5798%
# candle, taper, wax light: 5.6289%
# half track: 4.9909%
# dogsled, dog sled, dog sleigh: 4.2834%
#   1%|          | 11/1102 [00:01<02:34,  7.08it/s]
# Top-5 Predictions for the video id:  0010_0-3-6-10842732036
# restaurant, eating house, eating place, eatery: 27.0273%
# theater curtain, theatre curtain: 23.0738%
# bassoon: 14.7807%
# marimba, xylophone: 6.0117%
# steel drum: 4.7819%
#
# Top-5 Predictions for the video id:  0011_0-3-6-2-3-3-4-4-8103623344
# ocarina, sweet potato: 16.9343%
# restaurant, eating house, eating place, eatery: 13.4099%
# dining table, board: 7.8686%
# desk: 4.5309%
# bakery, bakeshop, bakehouse: 4.1378%
#   1%|          | 13/1102 [00:02<02:23,  7.61it/s]
# Top-5 Predictions for the video id:  0012_0-5-3-7-6-2-8-4-24105376284
# moving van: 17.5330%
# bullet train, bullet: 12.8398%
# photocopier: 9.4730%
# passenger car, coach, carriage: 9.1306%
# minibus: 8.6301%
#
# Top-5 Predictions for the video id:  0013_0-5-3-8-6-8-2-6-4805386826
# Welsh springer spaniel: 33.6901%
# Brittany spaniel: 29.0787%
# gyromitra: 13.2181%
# basset, basset hound: 3.4578%
# wire-haired fox terrier: 2.9208%
#   1%|▏         | 14/1102 [00:02<02:21,  7.67it/s]
# Top-5 Predictions for the video id:  0014_0-5-6-8272016056_edit
# potter's wheel: 59.9947%
# lab coat, laboratory coat: 5.2551%
# stretcher: 4.5747%
# barbershop: 3.3313%
# oxygen mask: 3.0769%
#
# Top-5 Predictions for the video id:  0015_0-6-1-9759583061
# pool table, billiard table, snooker table: 34.9676%
# wall clock: 8.8172%
# croquet ball: 7.6403%
# Petri dish: 5.5917%
# tennis ball: 3.6144%
#   1%|▏         | 16/1102 [00:02<02:19,  7.77it/s]
# Top-5 Predictions for the video id:  0016_0-6-6-1-5-8-2-5-14806615825
# potter's wheel: 61.7221%
# iron, smoothing iron: 17.3938%
# nipple: 4.4071%
# beaker: 4.4053%
# Petri dish: 2.6440%
#
# Top-5 Predictions for the video id:  0017_0-7-3-5856076073
# scoreboard: 10.3738%
# tennis ball: 8.1147%
# fire engine, fire truck: 5.0683%
# torch: 4.6415%
# comic book: 3.9524%
#   2%|▏         | 19/1102 [00:02<02:19,  7.79it/s]
# Top-5 Predictions for the video id:  0018_0-7-7-9-8-1-7-4-24407798174
# ski: 90.2314%
# bobsled, bobsleigh, bob: 3.2888%
# dogsled, dog sled, dog sleigh: 1.9902%
# snowmobile: 1.4551%
# stretcher: 0.9759%
#
# Top-5 Predictions for the video id:  0019_0-7-9-9-7-7-1-5-4307997715
# fox squirrel, eastern fox squirrel, Sciurus niger: 95.3870%
# grey fox, gray fox, Urocyon cinereoargenteus: 4.0745%
# kit fox, Vulpes macrotis: 0.4042%
# wood rabbit, cottontail, cottontail rabbit: 0.0967%
# hare: 0.0138%
#   2%|▏         | 20/1102 [00:03<02:17,  7.86it/s]
# Top-5 Predictions for the video id:  0020_0-8-0-0-3-9-3-9-7108003939
# pajama, pyjama, pj's, jammies: 8.6980%
# balance beam, beam: 7.8879%
# photocopier: 4.0504%
# crib, cot: 3.0423%
# feather boa, boa: 2.3383%
#
# Top-5 Predictions for the video id:  0021_0-8-0-8-6-5-4-5-4708086545
# agama: 5.6122%
# tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui: 5.1275%
# fox squirrel, eastern fox squirrel, Sciurus niger: 4.9952%
# marmot: 4.2800%
# mongoose: 4.1799%
#   2%|▏         | 22/1102 [00:03<02:18,  7.80it/s]
# Top-5 Predictions for the video id:  0022_0-8-7-7-9-6-5-5-6508779655
# plate: 18.6960%
# restaurant, eating house, eating place, eatery: 16.6330%
# dining table, board: 8.1666%
# Crock Pot: 7.0668%
# consomme: 5.5125%
#
# Top-5 Predictions for the video id:  0023_0-8-8-7346836088
# ping-pong ball: 38.0100%
# whistle: 6.3536%
# neck brace: 4.6343%
# bathing cap, swimming cap: 3.7324%
# tricycle, trike, velocipede: 3.6218%
#   2%|▏         | 25/1102 [00:03<02:15,  7.96it/s]
# Top-5 Predictions for the video id:  0024_0-9-3-5943645093
# African elephant, Loxodonta africana: 63.3650%
# Indian elephant, Elephas maximus: 32.5669%
# tusker: 2.2469%
# swimming trunks, bathing trunks: 0.3448%
# hog, pig, grunter, squealer, Sus scrofa: 0.3022%
#
# Top-5 Predictions for the video id:  0025_0-9-5-1-8-2-6-6-4009518266
# airliner: 64.1825%
# warplane, military plane: 29.2541%
# wing: 2.7389%
# space shuttle: 1.3083%
# projectile, missile: 1.0785%
#   2%|▏         | 26/1102 [00:03<02:17,  7.84it/s]
# Top-5 Predictions for the video id:  0026_0-9-9-8-0-5-8-5-4909980585
# ambulance: 17.5926%
# minibus: 14.6496%
# stretcher: 13.1670%
# limousine, limo: 12.7438%
# recreational vehicle, RV, R.V.: 9.9508%
#
# Top-5 Predictions for the video id:  0027_03chvdioZYI_85
# trombone: 29.4326%
# oboe, hautboy, hautbois: 11.6784%
# flute, transverse flute: 10.5321%
# cornet, horn, trumpet, trump: 8.9461%
# stage: 5.9007%
#   3%|▎         | 29/1102 [00:04<02:13,  8.02it/s]
# Top-5 Predictions for the video id:  0028_0P6FNr_6XWo_35
# oxygen mask: 5.5768%
# banjo: 5.5729%
# electric guitar: 4.6230%
# oboe, hautboy, hautbois: 3.6623%
# sax, saxophone: 3.5153%
#
# Top-5 Predictions for the video id:  0029_1-0-7-2-7-1-8-6-2810727186
# potter's wheel: 29.4646%
# toyshop: 9.1368%
# eggnog: 9.1065%
# maraca: 3.9285%
# mortar: 3.0411%
#   3%|▎         | 30/1102 [00:04<02:15,  7.91it/s]
# Top-5 Predictions for the video id:  0030_1-1-5-6-1-6-5-2-2811561652
# hair slide: 19.1100%
# maraca: 10.8801%
# piggy bank, penny bank: 6.9237%
# nipple: 6.1097%
# whistle: 4.0518%
#
# Top-5 Predictions for the video id:  0031_1-1-8-8-3-2-8-3-13711883283
# ski: 90.0950%
# snowmobile: 1.2529%
# puck, hockey puck: 0.7729%
# reel: 0.7473%
# bobsled, bobsleigh, bob: 0.7393%
#   3%|▎         | 33/1102 [00:04<02:21,  7.57it/s]
# Top-5 Predictions for the video id:  0032_1-2-0-9-0-9-1-6-3812090916_61
# corkscrew, bottle screw: 21.0736%
# whistle: 9.6433%
# pick, plectrum, plectron: 7.0266%
# lighter, light, igniter, ignitor: 4.3538%
# padlock: 3.8497%
#
# Top-5 Predictions for the video id:  0033_1-2-5-1-2-7-6-2-2512512762
# speedboat: 8.9592%
# lakeside, lakeshore: 4.3363%
# go-kart: 4.0416%
# convertible: 4.0233%
# seashore, coast, seacoast, sea-coast: 3.8942%
#   3%|▎         | 35/1102 [00:05<02:18,  7.70it/s]
# Top-5 Predictions for the video id:  0034_1-2-5-3344278125
# bicycle-built-for-two, tandem bicycle, tandem: 91.9200%
# mountain bike, all-terrain bike, off-roader: 3.3763%
# tricycle, trike, velocipede: 2.6454%
# moped: 1.1575%
# jinrikisha, ricksha, rickshaw: 0.4862%
#
# Top-5 Predictions for the video id:  0035_1-2-6-3176369126
# dogsled, dog sled, dog sleigh: 39.5634%
# snowmobile: 23.4207%
# ski: 16.5065%
# malamute, malemute, Alaskan malamute: 1.6480%
# German shepherd, German shepherd dog, German police dog, alsatian: 1.6139%
#   3%|▎         | 36/1102 [00:05<02:17,  7.75it/s]
# Top-5 Predictions for the video id:  0036_1-2-6-9-6-8-2-1-22212696821
# tabby, tabby cat: 23.1049%
# Egyptian cat: 11.4876%
# tiger cat: 7.6166%
# shower cap: 3.6122%
# nipple: 2.8544%
#
# Top-5 Predictions for the video id:  0037_1-3-9-9-9-6-4-3-3213999643
# plate: 40.1761%
# hot pot, hotpot: 31.7698%
# potpie: 5.6449%
# waffle iron: 5.1513%
# restaurant, eating house, eating place, eatery: 3.7122%
#   4%|▎         | 39/1102 [00:05<02:15,  7.83it/s]
# Top-5 Predictions for the video id:  0038_1-4-3-5-8-6-2-5-3114358625
# ski: 52.8185%
# snowplow, snowplough: 12.4699%
# alp: 10.7794%
# drilling platform, offshore rig: 4.0692%
# swing: 1.5711%
#
# Top-5 Predictions for the video id:  0039_1-4-4-4086629144
# radio telescope, radio reflector: 15.0306%
# solar dish, solar collector, solar furnace: 11.9817%
# schooner: 6.9110%
# water tower: 6.5359%
# beaker: 5.0895%
#   4%|▎         | 40/1102 [00:05<02:19,  7.60it/s]
# Top-5 Predictions for the video id:  0040_1-4-8-8-7-8-7-5-3914887875_56
# four-poster: 22.8341%
# mosquito net: 15.0712%
# binder, ring-binder: 8.8734%
# envelope: 6.5363%
# screen, CRT screen: 4.6836%
#
# Top-5 Predictions for the video id:  0041_1-5-0-0-4-9-7-8-2915004978_2
# lawn mower, mower: 63.0275%
# golfcart, golf cart: 5.3989%
# go-kart: 3.2590%
# tractor: 3.2461%
# Model T: 1.8554%
#   4%|▍         | 42/1102 [00:05<02:16,  7.77it/s]
# Top-5 Predictions for the video id:  0042_1-5-8-9-2-4-5-4-7815892454
# balance beam, beam: 38.8750%
# horizontal bar, high bar: 28.0120%
# racket, racquet: 5.0945%
# ballplayer, baseball player: 3.2515%
# parallel bars, bars: 3.1110%
#
# Top-5 Predictions for the video id:  0043_1-6-0-2796094160
# scuba diver: 99.7952%
# sea snake: 0.0561%
# tiger shark, Galeocerdo cuvieri: 0.0444%
# coral reef: 0.0259%
# snorkel: 0.0209%
#   4%|▍         | 44/1102 [00:06<02:20,  7.54it/s]
# Top-5 Predictions for the video id:  0044_1-6-0-7-7-6-4-6-7816077646
# planetarium: 31.1558%
# lakeside, lakeshore: 6.6940%
# parachute, chute: 3.8081%
# alp: 3.0122%
# airship, dirigible: 2.9564%
#
# Top-5 Predictions for the video id:  0045_1-6-8-0-7-6-7-4-3816807674
# neck brace: 21.6970%
# oboe, hautboy, hautbois: 6.4805%
# nipple: 5.7390%
# whistle: 4.3828%
# stethoscope: 4.2811%
#   4%|▍         | 47/1102 [00:06<02:18,  7.61it/s]
# Top-5 Predictions for the video id:  0046_1-6-8-5795643168
# geyser: 50.4554%
# valley, vale: 30.9155%
# promontory, headland, head, foreland: 3.4545%
# cliff, drop, drop-off: 3.1948%
# yawl: 1.4022%
#
# Top-5 Predictions for the video id:  0047_1-7-1-8-6-3-6-2-3417186362
# warplane, military plane: 32.0766%
# aircraft carrier, carrier, flattop, attack aircraft carrier: 16.4006%
# liner, ocean liner: 3.5949%
# projectile, missile: 3.0011%
# spotlight, spot: 2.3500%
#   4%|▍         | 49/1102 [00:06<02:17,  7.67it/s]
# Top-5 Predictions for the video id:  0048_1-7-2-5-5-0-7-5-25617255075
# abaya: 7.5130%
# parallel bars, bars: 6.3811%
# cliff dwelling: 4.3702%
# stretcher: 3.6802%
# bow: 2.8851%
#
# Top-5 Predictions for the video id:  0049_1-7-4-5-3-8-3-6-3017453836
# steel drum: 19.9976%
# unicycle, monocycle: 10.1172%
# stage: 7.3317%
# Sussex spaniel: 3.6645%
# rugby ball: 3.6101%
#   5%|▍         | 51/1102 [00:07<02:14,  7.80it/s]
# Top-5 Predictions for the video id:  0050_1-8-5-7127344185
# tennis ball: 47.1391%
# swimming trunks, bathing trunks: 4.9366%
# trimaran: 3.5589%
# racket, racquet: 3.4024%
# catamaran: 3.1213%
#
# Top-5 Predictions for the video id:  0051_1-8-7-1-1-9-6-6-5418711966
# snowplow, snowplough: 93.1088%
# snowmobile: 4.1928%
# chain saw, chainsaw: 0.5644%
# tractor: 0.4835%
# lawn mower, mower: 0.3606%
#   5%|▍         | 52/1102 [00:07<02:16,  7.67it/s]
# Top-5 Predictions for the video id:  0052_1-9-3-0-9-4-6-4-4719309464
# oxcart: 69.4456%
# Arabian camel, dromedary, Camelus dromedarius: 20.2382%
# Indian elephant, Elephas maximus: 4.7792%
# horse cart, horse-cart: 1.1166%
# tusker: 1.0265%
#
# Top-5 Predictions for the video id:  0053_1-9-3-2-8-0-1-3-3919328013
# comic book: 27.1961%
# Afghan hound, Afghan: 7.1560%
# Appenzeller: 3.9994%
# bloodhound, sleuthhound: 3.3441%
# tennis ball: 2.9833%
#   5%|▍         | 55/1102 [00:07<02:14,  7.80it/s]
# Top-5 Predictions for the video id:  0054_1-9-3-9-3-8-2-2-23719393822
# seashore, coast, seacoast, sea-coast: 20.8344%
# fountain: 15.0231%
# water tower: 14.8682%
# lakeside, lakeshore: 11.2506%
# speedboat: 5.8616%
#
# Top-5 Predictions for the video id:  0055_1-9-6-7-5-1-9-8-3119675198
# potter's wheel: 54.4028%
# eggnog: 4.8977%
# restaurant, eating house, eating place, eatery: 4.1783%
# toyshop: 4.0643%
# shoe shop, shoe-shop, shoe store: 3.8968%
#   5%|▌         | 57/1102 [00:07<02:12,  7.92it/s]
# Top-5 Predictions for the video id:  0056_2-0-0-3614591200
# promontory, headland, head, foreland: 52.2155%
# seashore, coast, seacoast, sea-coast: 18.7104%
# cliff, drop, drop-off: 7.2135%
# geyser: 3.3414%
# grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus: 2.7757%
#
# Top-5 Predictions for the video id:  0057_2-0-9-8159444209
# dam, dike, dyke: 77.6568%
# fireboat: 5.1814%
# lakeside, lakeshore: 3.9692%
# geyser: 3.8282%
# yawl: 1.9440%
#   5%|▌         | 59/1102 [00:08<02:11,  7.93it/s]
# Top-5 Predictions for the video id:  0058_2-4-3-5345273243
# stage: 67.8045%
# theater curtain, theatre curtain: 2.9890%
# unicycle, monocycle: 1.3026%
# panpipe, pandean pipe, syrinx: 1.2485%
# cornet, horn, trumpet, trump: 0.9106%
#
# Top-5 Predictions for the video id:  0059_2-5-7-6889839257
# ski: 61.6501%
# alp: 3.9059%
# snowplow, snowplough: 2.1221%
# shovel: 1.8552%
# stretcher: 1.7831%
#   6%|▌         | 61/1102 [00:08<02:09,  8.01it/s]
# Top-5 Predictions for the video id:  0060_2-6-5-12330534265
# dining table, board: 10.9146%
# eggnog: 8.0571%
# toyshop: 7.6350%
# restaurant, eating house, eating place, eatery: 6.3897%
# jigsaw puzzle: 3.8341%
#
# Top-5 Predictions for the video id:  0061_2-9-5-4309863295
# power drill: 7.7804%
# barbershop: 7.4126%
# oxygen mask: 4.3192%
# jersey, T-shirt, tee shirt: 4.1658%
# dumbbell: 3.7548%
#   6%|▌         | 63/1102 [00:08<02:10,  7.95it/s]
# Top-5 Predictions for the video id:  0062_2EMSeADyrrQ_35
# rock beauty, Holocanthus tricolor: 22.9797%
# tennis ball: 9.0473%
# shopping basket: 6.8172%
# space heater: 5.5584%
# indigo bunting, indigo finch, indigo bird, Passerina cyanea: 2.8479%
#
# Top-5 Predictions for the video id:  0063_2Ng8UYBFhbU_91
# meat loaf, meatloaf: 13.7085%
# dishrag, dishcloth: 13.4374%
# hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa: 7.9136%
# pot, flowerpot: 4.4932%
# Crock Pot: 3.2832%
#   6%|▌         | 65/1102 [00:08<02:13,  7.79it/s]
# Top-5 Predictions for the video id:  0064_2Tm26dLw29A_69
# lawn mower, mower: 22.3871%
# harvester, reaper: 19.1010%
# tractor: 13.2705%
# mobile home, manufactured home: 10.1148%
# solar dish, solar collector, solar furnace: 3.2780%
#
# Top-5 Predictions for the video id:  0065_2aG9AaxuGSU_148
# television, television system: 40.9287%
# home theater, home theatre: 25.5993%
# monitor: 16.3699%
# screen, CRT screen: 4.4081%
# laptop, laptop computer: 3.1461%
#   6%|▌         | 66/1102 [00:09<02:12,  7.82it/s]
# Top-5 Predictions for the video id:  0066_2cCnDHUV0W8_35
# miniskirt, mini: 28.0900%
# abaya: 27.4705%
# overskirt: 11.6431%
# trench coat: 5.7322%
# cowboy boot: 3.9417%
#
# Top-5 Predictions for the video id:  0067_2h1Mj2ymyj8_121
# unicycle, monocycle: 40.2339%
# jinrikisha, ricksha, rickshaw: 10.7405%
# tricycle, trike, velocipede: 8.8134%
# bicycle-built-for-two, tandem bicycle, tandem: 7.1734%
# oxcart: 4.2945%
#   6%|▋         | 69/1102 [00:09<02:14,  7.71it/s]
# Top-5 Predictions for the video id:  0068_3-0-4-4343808304
# grocery store, grocery, food market, market: 56.8886%
# toyshop: 16.8737%
# confectionery, confectionary, candy store: 12.5146%
# banana: 2.6219%
# vending machine: 2.0241%
#
# Top-5 Predictions for the video id:  0069_3-0-5-3-4-3-5-2-4730534352
# oxcart: 30.2290%
# potter's wheel: 7.7686%
# stretcher: 5.9041%
# assault rifle, assault gun: 4.2416%
# sturgeon: 2.9993%
#   6%|▋         | 70/1102 [00:09<02:15,  7.59it/s]
# Top-5 Predictions for the video id:  0070_3-3-6-8-2-7-6-6-3533682766
# vizsla, Hungarian pointer: 18.0677%
# bloodhound, sleuthhound: 12.2340%
# Rhodesian ridgeback: 7.7773%
# bull mastiff: 3.9307%
# malinois: 3.6033%
#
# Top-5 Predictions for the video id:  0071_3-4-9-8-4-7-4-8-4434984748
# airliner: 49.1064%
# sports car, sport car: 8.9615%
# racer, race car, racing car: 7.6791%
# warplane, military plane: 3.7220%
# mobile home, manufactured home: 3.2780%
#   7%|▋         | 72/1102 [00:09<02:15,  7.62it/s]
# Top-5 Predictions for the video id:  0072_3-5-0-4261181350
# library: 15.8419%
# potter's wheel: 12.3590%
# guinea pig, Cavia cobaya: 12.2113%
# toyshop: 9.7891%
# barbershop: 6.3820%
#
# Top-5 Predictions for the video id:  0073_3-5-8-9-9-5-9-8-4335899598
# shovel: 54.1489%
# ski: 20.4652%
# ski mask: 12.0272%
# chain saw, chainsaw: 2.4026%
# bobsled, bobsleigh, bob: 2.3907%
#   7%|▋         | 75/1102 [00:10<02:12,  7.74it/s]
# Top-5 Predictions for the video id:  0074_3-6-5-3-3-4-4-5-23036533445
# toyshop: 8.3309%
# maillot, tank suit: 6.3982%
# kimono: 5.3921%
# sarong: 3.5969%
# maillot: 2.9890%
#
# Top-5 Predictions for the video id:  0075_3-7-0-7-1-5-3-0-4937071530
# ping-pong ball: 14.6644%
# nipple: 5.4701%
# torch: 4.9702%
# screen, CRT screen: 4.3836%
# spaghetti squash: 3.0403%
#   7%|▋         | 77/1102 [00:10<02:08,  7.99it/s]
# Top-5 Predictions for the video id:  0076_3-7-3-13269577373
# lifeboat: 34.4908%
# speedboat: 29.8783%
# trimaran: 11.5310%
# fireboat: 9.6292%
# yawl: 5.5522%
#
# Top-5 Predictions for the video id:  0077_3-7-3-7-1-7-0-1-2537371701
# plunger, plumber's helper: 8.9009%
# dumbbell: 7.2793%
# potter's wheel: 6.6854%
# gasmask, respirator, gas helmet: 6.0035%
# maraca: 5.8419%
#   7%|▋         | 78/1102 [00:10<02:11,  7.77it/s]
# Top-5 Predictions for the video id:  0078_3-7-5-4-7-7-8-9-8037547789
# studio couch, day bed: 20.5236%
# four-poster: 13.0123%
# quilt, comforter, comfort, puff: 11.1805%
# hair spray: 4.9677%
# window shade: 3.3090%
#
# Top-5 Predictions for the video id:  0079_3-7-5-6-6-4-1-7-3437566417
# bicycle-built-for-two, tandem bicycle, tandem: 28.0281%
# motor scooter, scooter: 18.0278%
# moped: 10.6405%
# crash helmet: 7.9676%
# unicycle, monocycle: 7.8388%
#   7%|▋         | 81/1102 [00:11<02:10,  7.84it/s]
# Top-5 Predictions for the video id:  0080_3-9-0-6-4-2-6-6-3339064266
# horizontal bar, high bar: 22.1114%
# parallel bars, bars: 13.9227%
# croquet ball: 8.7384%
# tricycle, trike, velocipede: 7.6724%
# swing: 3.3219%
#
# Top-5 Predictions for the video id:  0081_4-0-6-7-6-1-4-5-4540676145
# axolotl, mud puppy, Ambystoma mexicanum: 28.5932%
# hamster: 24.2028%
# piggy bank, penny bank: 6.5011%
# nipple: 5.2234%
# Angora, Angora rabbit: 2.2926%
#   8%|▊         | 83/1102 [00:11<02:03,  8.26it/s]
# Top-5 Predictions for the video id:  0082_4-2-5-6-5-3-6-5-16342565365
# acoustic guitar: 86.9789%
# electric guitar: 9.6700%
# neck brace: 0.7793%
# pick, plectrum, plectron: 0.6123%
# banjo: 0.3772%
#
# Top-5 Predictions for the video id:  0083_4-3-3-1-0-6-4-0-8743310640
# water jug: 24.7156%
# beaker: 17.9541%
# hourglass: 12.4268%
# Petri dish: 6.2065%
# oxygen mask: 4.2581%
#   8%|▊         | 84/1102 [00:11<02:06,  8.05it/s]
# Top-5 Predictions for the video id:  0084_4-3-4-8736778434
# joystick: 11.8122%
# remote control, remote: 5.4620%
# hand-held computer, hand-held microcomputer: 5.4021%
# oscilloscope, scope, cathode-ray oscilloscope, CRO: 4.7615%
# cellular telephone, cellular phone, cellphone, cell, mobile phone: 4.6924%
#
# Top-5 Predictions for the video id:  0085_4-3-5-6-0-8-0-8-5543560808
# shovel: 8.6908%
# bobsled, bobsleigh, bob: 6.7516%
# yurt: 3.6815%
# Irish wolfhound: 3.6662%
# hog, pig, grunter, squealer, Sus scrofa: 3.4721%
#   8%|▊         | 87/1102 [00:11<02:14,  7.56it/s]
# Top-5 Predictions for the video id:  0086_4-3-5-9059723435
# nipple: 73.4687%
# cradle: 5.3283%
# diaper, nappy, napkin: 4.8853%
# tub, vat: 3.1955%
# ear, spike, capitulum: 2.5764%
#
# Top-5 Predictions for the video id:  0087_4-3-7-4396869437
# ski: 62.1982%
# bobsled, bobsleigh, bob: 13.3328%
# dogsled, dog sled, dog sleigh: 8.6053%
# snowmobile: 7.4596%
# shovel: 1.6614%
#   8%|▊         | 88/1102 [00:11<02:11,  7.69it/s]
# Top-5 Predictions for the video id:  0088_4-3-7-4889733437
# tripod: 5.4908%
# guillotine: 4.0252%
# harp: 3.0746%
# joystick: 2.4154%
# candle, taper, wax light: 2.3334%
#
# Top-5 Predictions for the video id:  0089_4-3-8-2-7-7-4-3-9043827743
# valley, vale: 67.9513%
# lakeside, lakeshore: 8.2158%
# seashore, coast, seacoast, sea-coast: 1.7646%
# head cabbage: 1.2822%
# alp: 1.2739%
#   8%|▊         | 91/1102 [00:12<02:11,  7.70it/s]
# Top-5 Predictions for the video id:  0090_4-4-7-5-2-9-5-4-4744752954
# paddle, boat paddle: 69.9483%
# canoe: 21.7078%
# barracouta, snoek: 2.1697%
# yawl: 1.4623%
# gar, garfish, garpike, billfish, Lepisosteus osseus: 1.1867%
#
# Top-5 Predictions for the video id:  0091_4-5-0-1-4-3-5-1-15645014351
# snowplow, snowplough: 23.1540%
# parallel bars, bars: 16.5701%
# puck, hockey puck: 14.6715%
# bobsled, bobsleigh, bob: 6.9073%
# amphibian, amphibious vehicle: 3.8160%
#   8%|▊         | 93/1102 [00:12<02:05,  8.01it/s]
# Top-5 Predictions for the video id:  0092_4-5-7-1-7-9-4-4-5945717944
# warplane, military plane: 72.8837%
# airliner: 8.8820%
# wing: 6.7223%
# space shuttle: 4.3859%
# bow: 2.4760%
#
# Top-5 Predictions for the video id:  0093_4-5-7-5265004457
# plate: 12.3658%
# candle, taper, wax light: 10.4903%
# trifle: 4.9494%
# hair slide: 4.4524%
# ice cream, icecream: 4.3883%
#   9%|▊         | 94/1102 [00:12<02:11,  7.69it/s]
# Top-5 Predictions for the video id:  0094_4-5-9-2-3-0-7-9-15245923079
# sturgeon: 35.4434%
# gar, garfish, garpike, billfish, Lepisosteus osseus: 9.7309%
# coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch: 9.2981%
# grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus: 7.8149%
# barracouta, snoek: 5.6505%
#
# Top-5 Predictions for the video id:  0095_4-6-1-9-8-5-2-4-25546198524
# ballplayer, baseball player: 73.5525%
# baseball: 21.4157%
# scoreboard: 1.0818%
# racket, racquet: 1.0811%
# pole: 0.6956%
#   9%|▊         | 96/1102 [00:13<02:15,  7.44it/s]
# Top-5 Predictions for the video id:  0096_4-7-1-1-2-8-3-0-25247112830
# speedboat: 89.1187%
# sandbar, sand bar: 3.2168%
# canoe: 1.1479%
# catamaran: 0.8856%
# container ship, containership, container vessel: 0.5678%
#
# Top-5 Predictions for the video id:  0097_4-7-9-4959184479
# theater curtain, theatre curtain: 11.6676%
# Afghan hound, Afghan: 10.5618%
# torch: 4.1420%
# unicycle, monocycle: 3.3103%
# Welsh springer spaniel: 3.3026%
#   9%|▉         | 98/1102 [00:13<02:12,  7.59it/s]
# Top-5 Predictions for the video id:  0098_4-7-9-5224564479
# lipstick, lip rouge: 12.4349%
# punching bag, punch bag, punching ball, punchball: 9.2012%
# bookcase: 8.0137%
# turnstile: 7.1568%
# lighter, light, igniter, ignitor: 4.1218%
#
# Top-5 Predictions for the video id:  0099_4-7-9-5897473479
# stretcher: 48.4355%
# broom: 19.4663%
# academic gown, academic robe, judge's robe: 2.4435%
# maypole: 2.1959%
# Loafer: 1.8344%
#   9%|▉         | 101/1102 [00:13<02:12,  7.53it/s]
# Top-5 Predictions for the video id:  0100_4-7-9-7-6-5-8-0-2647976580
# balance beam, beam: 51.8487%
# horizontal bar, high bar: 15.5110%
# parallel bars, bars: 10.4668%
# ping-pong ball: 9.0338%
# maillot, tank suit: 4.7662%
#
# Top-5 Predictions for the video id:  0101_4-8-4-5-2-8-6-4-12748452864
# geyser: 70.7554%
# volcano: 2.7387%
# airship, dirigible: 2.1916%
# fireboat: 1.4685%
# beacon, lighthouse, beacon light, pharos: 0.9378%
#   9%|▉         | 103/1102 [00:13<02:11,  7.58it/s]
# Top-5 Predictions for the video id:  0102_4-8-9-2-5-7-3-1-3848925731
# ice lolly, lolly, lollipop, popsicle: 30.7264%
# maraca: 14.0335%
# nipple: 11.4169%
# whistle: 3.8696%
# diaper, nappy, napkin: 3.6447%
#
# Top-5 Predictions for the video id:  0103_4-9-0-4-8-4-8-7-3949048487
# geyser: 99.8259%
# volcano: 0.0421%
# seashore, coast, seacoast, sea-coast: 0.0197%
# beacon, lighthouse, beacon light, pharos: 0.0117%
# hay: 0.0115%
#  10%|▉         | 105/1102 [00:14<02:08,  7.74it/s]
# Top-5 Predictions for the video id:  0104_4_mAU3U33fU_224
# thresher, thrasher, threshing machine: 18.0561%
# fire engine, fire truck: 16.1037%
# tractor: 12.5859%
# snowplow, snowplough: 7.4495%
# trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi: 5.9409%
#
# Top-5 Predictions for the video id:  0105_5-0-2-9044555502
# trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi: 17.3022%
# limousine, limo: 13.7519%
# recreational vehicle, RV, R.V.: 10.0079%
# passenger car, coach, carriage: 8.0405%
# moving van: 7.4675%
#  10%|▉         | 107/1102 [00:14<02:07,  7.82it/s]
# Top-5 Predictions for the video id:  0106_5-0-6-7-7-5-7-6-14950677576_1
# mobile home, manufactured home: 36.6857%
# go-kart: 6.0776%
# garbage truck, dustcart: 4.3465%
# lakeside, lakeshore: 3.4010%
# recreational vehicle, RV, R.V.: 3.3481%
#
# Top-5 Predictions for the video id:  0107_5-2-4-5-8-0-7-9-4752458079
# mobile home, manufactured home: 7.2513%
# pedestal, plinth, footstall: 5.4193%
# guillotine: 4.7547%
# bell cote, bell cot: 4.4704%
# submarine, pigboat, sub, U-boat: 4.3032%
#  10%|▉         | 109/1102 [00:14<02:05,  7.89it/s]
# Top-5 Predictions for the video id:  0108_5-3-4-9966677534
# speedboat: 25.0549%
# lifeboat: 16.7740%
# canoe: 16.0911%
# fireboat: 9.4293%
# snorkel: 7.9994%
#
# Top-5 Predictions for the video id:  0109_5-3-7-1-9-2-1-2-3453719212
# printer: 14.7183%
# photocopier: 8.0648%
# plate: 7.4714%
# toaster: 7.2778%
# cleaver, meat cleaver, chopper: 5.3874%
#  10%|█         | 111/1102 [00:14<02:03,  8.05it/s]
# Top-5 Predictions for the video id:  0110_5-4-0-2405298540
# trimaran: 74.0233%
# catamaran: 13.2103%
# speedboat: 5.7367%
# yawl: 1.9589%
# seashore, coast, seacoast, sea-coast: 0.8907%
#
# Top-5 Predictions for the video id:  0111_5-4-2-6-1-5-0-7-5654261507
# ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus: 9.6398%
# Norwegian elkhound, elkhound: 8.3697%
# ox: 5.4078%
# dogsled, dog sled, dog sleigh: 3.6922%
# English setter: 3.2701%
#  10%|█         | 112/1102 [00:15<02:05,  7.88it/s]
# Top-5 Predictions for the video id:  0112_5-4-2-6-3-7-5-4-7854263754
# skunk, polecat, wood pussy: 28.1597%
# Old English sheepdog, bobtail: 7.5091%
# valley, vale: 6.4346%
# American alligator, Alligator mississipiensis: 5.1304%
# komondor: 4.1310%
#
# Top-5 Predictions for the video id:  0113_5-4-3-5-0-8-5-4-13654350854_22
# laptop, laptop computer: 23.8081%
# library: 17.2314%
# potter's wheel: 7.3541%
# washer, automatic washer, washing machine: 4.9900%
# stethoscope: 4.6290%
#  10%|█         | 114/1102 [00:15<02:07,  7.77it/s]
# Top-5 Predictions for the video id:  0114_5-4-5-2-2-4-8-5-8454522485
# hot pot, hotpot: 49.6443%
# consomme: 8.8958%
# plate: 7.7669%
# frying pan, frypan, skillet: 6.8989%
# Dutch oven: 4.4427%
#
# Top-5 Predictions for the video id:  0115_5-4-5-4-1-8-6-5-8254541865_29
# Sussex spaniel: 30.7806%
# Irish setter, red setter: 17.2273%
# briard: 14.8614%
# Airedale, Airedale terrier: 6.7738%
# Irish terrier: 2.5271%
#  11%|█         | 117/1102 [00:15<02:04,  7.93it/s]
# Top-5 Predictions for the video id:  0116_5-6-5-5-1-6-7-5-23256551675
# face powder: 62.6877%
# consomme: 28.7079%
# espresso: 1.4723%
# Petri dish: 1.2349%
# beaker: 0.5596%
#
# Top-5 Predictions for the video id:  0117_5-6-6-3042970566
# solar dish, solar collector, solar furnace: 6.9337%
# standard poodle: 6.5854%
# steel drum: 3.6910%
# hoopskirt, crinoline: 3.1906%
# Cardigan, Cardigan Welsh corgi: 2.9434%
#  11%|█         | 118/1102 [00:15<02:05,  7.82it/s]
# Top-5 Predictions for the video id:  0118_5-6-7-7-6-0-9-9-3756776099
# lawn mower, mower: 8.6979%
# apiary, bee house: 7.3189%
# water buffalo, water ox, Asiatic buffalo, Bubalus bubalis: 5.4236%
# milk can: 3.7698%
# sundial: 3.0976%
#
# Top-5 Predictions for the video id:  0119_5-7-0-7-8-9-1-3-4257078913
# theater curtain, theatre curtain: 32.5871%
# vestment: 21.7120%
# academic gown, academic robe, judge's robe: 14.8932%
# Afghan hound, Afghan: 4.2963%
# altar: 2.4350%
#  11%|█         | 121/1102 [00:16<02:07,  7.72it/s]
# Top-5 Predictions for the video id:  0120_5-7-5-3760841575
# canoe: 29.2222%
# speedboat: 15.7935%
# sandbar, sand bar: 9.0619%
# paddle, boat paddle: 8.1636%
# lakeside, lakeshore: 8.0853%
#
# Top-5 Predictions for the video id:  0121_5-7-6-1-2-1-4-3-17357612143
# jacamar: 56.5022%
# bulbul: 14.2953%
# squirrel monkey, Saimiri sciureus: 5.7082%
# brambling, Fringilla montifringilla: 4.1074%
# titi, titi monkey: 3.8150%
#  11%|█         | 122/1102 [00:16<02:06,  7.74it/s]
# Top-5 Predictions for the video id:  0122_5-7-6-9-5-4-8-2-5457695482
# swimming trunks, bathing trunks: 24.1289%
# diaper, nappy, napkin: 15.2859%
# bathtub, bathing tub, bath, tub: 11.5346%
# tub, vat: 9.0694%
# parallel bars, bars: 7.1058%
#
# Top-5 Predictions for the video id:  0123_5-9-0-1-9-6-9-0-5259019690
# pinwheel: 64.9620%
# whistle: 10.5163%
# rubber eraser, rubber, pencil eraser: 5.0325%
# pick, plectrum, plectron: 2.5951%
# jigsaw puzzle: 2.2884%
#  11%|█▏        | 124/1102 [00:16<02:05,  7.79it/s]
# Top-5 Predictions for the video id:  0124_5-9-1-5611850591
# bobsled, bobsleigh, bob: 12.5232%
# barbell: 9.6555%
# balance beam, beam: 6.8340%
# stretcher: 4.8798%
# television, television system: 4.5949%
#
# Top-5 Predictions for the video id:  0125_5-9-4-9166960594
# maypole: 39.7981%
# ski: 8.2665%
# oxcart: 5.6904%
# jinrikisha, ricksha, rickshaw: 4.3732%
# Afghan hound, Afghan: 3.1071%
#  11%|█▏        | 126/1102 [00:16<02:07,  7.66it/s]
# Top-5 Predictions for the video id:  0126_5-9-7-5-7-9-9-8-2859757998
# valley, vale: 34.2188%
# cliff, drop, drop-off: 10.7689%
# fountain: 10.6228%
# indri, indris, Indri indri, Indri brevicaudatus: 5.2414%
# pedestal, plinth, footstall: 1.4909%
#
# Top-5 Predictions for the video id:  0127_5541389947
# bobsled, bobsleigh, bob: 21.5143%
# maillot: 13.8002%
# throne: 3.7697%
# kimono: 2.4866%
# balance beam, beam: 2.3934%
#  12%|█▏        | 129/1102 [00:17<02:02,  7.94it/s]
# Top-5 Predictions for the video id:  0128_5948238182
# balance beam, beam: 12.0763%
# bathtub, bathing tub, bath, tub: 10.6159%
# cradle: 7.1204%
# tub, vat: 6.1445%
# parallel bars, bars: 4.9634%
#
# Top-5 Predictions for the video id:  0129_5pZ8Z7icwxE_276
# bookshop, bookstore, bookstall: 15.6835%
# library: 10.7101%
# refrigerator, icebox: 4.8201%
# medicine chest, medicine cabinet: 4.5761%
# carton: 4.3272%
#  12%|█▏        | 131/1102 [00:17<02:01,  8.00it/s]
# Top-5 Predictions for the video id:  0130_6-0-7-6496350607
# soccer ball: 30.9839%
# rugby ball: 15.0943%
# croquet ball: 14.8819%
# Saluki, gazelle hound: 5.9458%
# football helmet: 5.6038%
#
# Top-5 Predictions for the video id:  0131_6-0-9-5-1-4-3-4-3260951434
# ocarina, sweet potato: 11.7015%
# hair slide: 5.0765%
# acorn squash: 3.6733%
# platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus: 3.5050%
# quill, quill pen: 3.0966%
#  12%|█▏        | 132/1102 [00:17<02:01,  7.96it/s]
# Top-5 Predictions for the video id:  0132_6-1-0-8-4-3-3-3-2461084333
# candle, taper, wax light: 9.7379%
# Petri dish: 8.3365%
# hair slide: 8.3164%
# consomme: 5.3571%
# trifle: 4.6003%
#
# Top-5 Predictions for the video id:  0133_6-2-2-4-7-1-0-3-6562247103
# dumbbell: 27.8001%
# parallel bars, bars: 7.8264%
# horizontal bar, high bar: 6.0628%
# ping-pong ball: 5.4728%
# notebook, notebook computer: 4.6490%
#  12%|█▏        | 135/1102 [00:18<02:04,  7.78it/s]
# Top-5 Predictions for the video id:  0134_6-3-7-7169142637
# electric locomotive: 82.5975%
# passenger car, coach, carriage: 11.9736%
# streetcar, tram, tramcar, trolley, trolley car: 2.6360%
# steam locomotive: 0.4965%
# garbage truck, dustcart: 0.4787%
#
# Top-5 Predictions for the video id:  0135_6-4-0-3-0-0-4-4-22064030044
# basketball: 67.7084%
# football helmet: 9.1052%
# German shepherd, German shepherd dog, German police dog, alsatian: 3.2086%
# soccer ball: 2.4058%
# scoreboard: 2.3883%
#  12%|█▏        | 136/1102 [00:18<02:06,  7.66it/s]
# Top-5 Predictions for the video id:  0136_6-4-4-8-8-6-2-5-8164488625
# caldron, cauldron: 21.0729%
# frying pan, frypan, skillet: 13.9568%
# wok: 11.9441%
# Dutch oven: 6.4416%
# barrow, garden cart, lawn cart, wheelbarrow: 6.0941%
#
# Top-5 Predictions for the video id:  0137_6-5-9-3859686659
# steel drum: 16.8230%
# toyshop: 9.2881%
# confectionery, confectionary, candy store: 4.2424%
# fountain: 3.6757%
# desk: 3.3358%
#  13%|█▎        | 138/1102 [00:18<02:10,  7.37it/s]
# Top-5 Predictions for the video id:  0138_6-6-1-2641881661
# canoe: 35.6317%
# paddle, boat paddle: 17.7347%
# drilling platform, offshore rig: 9.8829%
# grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus: 4.3000%
# snorkel: 3.8251%
#
# Top-5 Predictions for the video id:  0139_6-6-6-7-7-0-2-9-6866677029_1
# stingray: 38.1402%
# snorkel: 15.2338%
# great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias: 5.0021%
# swimming trunks, bathing trunks: 4.7619%
# bathing cap, swimming cap: 2.7673%
#  13%|█▎        | 140/1102 [00:18<02:08,  7.51it/s]
# Top-5 Predictions for the video id:  0140_6-6-8-7-5-4-8-7-8066875487_24
# cab, hack, taxi, taxicab: 21.2469%
# streetcar, tram, tramcar, trolley, trolley car: 16.0539%
# police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria: 15.7112%
# ambulance: 11.8477%
# racer, race car, racing car: 6.6008%
#
# Top-5 Predictions for the video id:  0141_6-7-0-1-4-8-8-0-9267014880
# bee: 71.3690%
# ant, emmet, pismire: 10.9912%
# ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle: 2.5369%
# cauliflower: 1.9059%
# hair slide: 1.7287%
#  13%|█▎        | 142/1102 [00:19<02:08,  7.45it/s]
# Top-5 Predictions for the video id:  0142_6-8-1-3-0-3-6-5-11768130365
# oxcart: 58.9962%
# horse cart, horse-cart: 23.9058%
# dogsled, dog sled, dog sleigh: 4.4794%
# Great Dane: 4.3957%
# ox: 2.4044%
#
# Top-5 Predictions for the video id:  0143_6-8-5-2652653685
# mobile home, manufactured home: 13.7692%
# tow truck, tow car, wrecker: 9.3429%
# limousine, limo: 8.3100%
# amphibian, amphibious vehicle: 7.1317%
# garbage truck, dustcart: 5.7384%
#  13%|█▎        | 144/1102 [00:19<02:04,  7.69it/s]
# Top-5 Predictions for the video id:  0144_6-gEVb8H_fk_649
# envelope: 14.6930%
# rubber eraser, rubber, pencil eraser: 6.4294%
# sunglass: 4.0291%
# swimming trunks, bathing trunks: 3.7677%
# sunglasses, dark glasses, shades: 3.3901%
#
# Top-5 Predictions for the video id:  0145_7-0-7-8-4-7-5-8-14570784758
# croquet ball: 25.5098%
# Irish wolfhound: 11.7390%
# chain saw, chainsaw: 5.5277%
# Airedale, Airedale terrier: 5.0136%
# Bouvier des Flandres, Bouviers des Flandres: 4.8378%
#  13%|█▎        | 147/1102 [00:19<02:03,  7.72it/s]
# Top-5 Predictions for the video id:  0146_7-1-5-1-5-3-3-7-7171515337
# capuchin, ringtail, Cebus capucinus: 52.9895%
# titi, titi monkey: 13.6432%
# macaque: 9.8378%
# gibbon, Hylobates lar: 7.4387%
# patas, hussar monkey, Erythrocebus patas: 4.4453%
#
# Top-5 Predictions for the video id:  0147_7-1-6-7637947716
# bearskin, busby, shako: 6.4773%
# accordion, piano accordion, squeeze box: 5.5660%
# abaya: 4.9736%
# moving van: 3.4563%
# fur coat: 3.3144%
#  13%|█▎        | 148/1102 [00:19<02:04,  7.64it/s]
# Top-5 Predictions for the video id:  0148_7-1-8-0-6-6-5-3-2471806653
# umbrella: 7.0191%
# horizontal bar, high bar: 6.2065%
# feather boa, boa: 4.8944%
# brassiere, bra, bandeau: 4.7959%
# swing: 4.3358%
#
# Top-5 Predictions for the video id:  0149_7-1-8-7-4-8-0-6-2471874806
# marimba, xylophone: 43.9263%
# military uniform: 7.1480%
# tobacco shop, tobacconist shop, tobacconist: 3.1457%
# jinrikisha, ricksha, rickshaw: 2.9907%
# mobile home, manufactured home: 2.5646%
#  14%|█▎        | 150/1102 [00:20<02:09,  7.37it/s]
# Top-5 Predictions for the video id:  0150_7-2-3-4-0-4-6-7-3872340467
# Dutch oven: 65.4130%
# frying pan, frypan, skillet: 10.7603%
# caldron, cauldron: 7.7669%
# stove: 4.6296%
# Crock Pot: 2.5748%
#
# Top-5 Predictions for the video id:  0151_7-2-5-2-4-9-1-1-3572524911
# diaper, nappy, napkin: 11.2092%
# nipple: 10.9410%
# candle, taper, wax light: 6.6078%
# bathtub, bathing tub, bath, tub: 6.3215%
# piggy bank, penny bank: 5.4085%
#  14%|█▍        | 152/1102 [00:20<02:16,  6.94it/s]
# Top-5 Predictions for the video id:  0152_7-3-2-8-5-5-7-0-2773285570_7
# sea snake: 27.9529%
# spiny lobster, langouste, rock lobster, crawfish, crayfish, sea crawfish: 19.7557%
# electric ray, crampfish, numbfish, torpedo: 17.9211%
# stingray: 8.4832%
# eel: 8.0073%
#
# Top-5 Predictions for the video id:  0153_7-3-3-3-1-1-7-8-5973331178
# abaya: 7.7607%
# overskirt: 6.8564%
# miniskirt, mini: 5.0705%
# horizontal bar, high bar: 4.5533%
# pole: 4.3010%
#  14%|█▍        | 155/1102 [00:20<02:04,  7.62it/s]
# Top-5 Predictions for the video id:  0154_7-3-3-8-1-7-0-5-5773381705
# hot pot, hotpot: 32.5968%
# American lobster, Northern lobster, Maine lobster, Homarus americanus: 16.1012%
# king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica: 9.1699%
# gyromitra: 8.4618%
# rotisserie: 6.1540%
#
# Top-5 Predictions for the video id:  0155_7-3-3-9823355733
# croquet ball: 15.7866%
# Scottish deerhound, deerhound: 10.9400%
# unicycle, monocycle: 7.4836%
# Irish wolfhound: 4.2949%
# golf ball: 4.0514%
#  14%|█▍        | 156/1102 [00:20<02:12,  7.15it/s]
# Top-5 Predictions for the video id:  0156_7-3-8-8-3-3-3-0-6873883330_5
# stingray: 18.2102%
# coral reef: 18.2055%
# electric ray, crampfish, numbfish, torpedo: 14.6022%
# hammerhead, hammerhead shark: 8.7807%
# loggerhead, loggerhead turtle, Caretta caretta: 7.9907%
#
# Top-5 Predictions for the video id:  0157_7-4-3-9701238743
# racket, racquet: 26.0962%
# croquet ball: 9.2648%
# golf ball: 8.2828%
# ballplayer, baseball player: 4.7838%
# bow: 3.6052%
#  14%|█▍        | 158/1102 [00:21<02:08,  7.34it/s]
# Top-5 Predictions for the video id:  0158_7-5-4-8-3-8-3-6-25975483836
# ballplayer, baseball player: 79.2168%
# baseball: 15.6934%
# racket, racquet: 1.1217%
# basenji: 0.7751%
# volleyball: 0.2540%
#
# Top-5 Predictions for the video id:  0159_7-6-3-1-6-7-9-2-7876316792_13
# geyser: 7.9953%
# umbrella: 7.5237%
# shovel: 5.1842%
# swab, swob, mop: 4.1523%
# crutch: 3.9741%
#  15%|█▍        | 160/1102 [00:21<02:08,  7.34it/s]
# Top-5 Predictions for the video id:  0160_7-7-0-2652639770
# bicycle-built-for-two, tandem bicycle, tandem: 74.4222%
# mountain bike, all-terrain bike, off-roader: 21.9802%
# unicycle, monocycle: 1.0131%
# tricycle, trike, velocipede: 0.5888%
# Arabian camel, dromedary, Camelus dromedarius: 0.4417%
#
# Top-5 Predictions for the video id:  0161_7-7-2-8-9-8-8-7-3077289887
# grocery store, grocery, food market, market: 61.2507%
# toyshop: 17.0377%
# tobacco shop, tobacconist shop, tobacconist: 4.4026%
# confectionery, confectionary, candy store: 3.0072%
# bakery, bakeshop, bakehouse: 2.7813%
#  15%|█▍        | 162/1102 [00:21<02:06,  7.44it/s]
# Top-5 Predictions for the video id:  0162_7-7-4-0-8-2-3-2-21577408232
# croquet ball: 13.7232%
# soccer ball: 11.3303%
# golf ball: 6.9920%
# rugby ball: 5.0592%
# Rhodesian ridgeback: 2.8236%
#
# Top-5 Predictions for the video id:  0163_7-8-4-11617872784
# coral reef: 81.8129%
# sea snake: 8.6412%
# scuba diver: 3.1897%
# rock beauty, Holocanthus tricolor: 2.1236%
# brain coral: 1.6884%
#  15%|█▍        | 164/1102 [00:21<02:02,  7.66it/s]
# Top-5 Predictions for the video id:  0164_7-8-4-4-0-9-0-9-3778440909
# garbage truck, dustcart: 13.2817%
# thresher, thrasher, threshing machine: 5.5753%
# horse cart, horse-cart: 5.1698%
# komondor: 3.9112%
# Irish wolfhound: 3.3930%
#
# Top-5 Predictions for the video id:  0165_7-8-5-4189422785
# croquet ball: 28.1015%
# maypole: 18.9727%
# lawn mower, mower: 6.4617%
# soccer ball: 4.2242%
# schipperke: 1.9453%
#  15%|█▌        | 167/1102 [00:22<02:05,  7.46it/s]
# Top-5 Predictions for the video id:  0166_7-9-1-9-1-3-1-5-5879191315
# swing: 39.0959%
# horizontal bar, high bar: 11.3429%
# ballplayer, baseball player: 8.5840%
# bow: 8.4823%
# volleyball: 4.1888%
#
# Top-5 Predictions for the video id:  0167_7-9-2-5805821792
# toyshop: 19.6371%
# tobacco shop, tobacconist shop, tobacconist: 10.8150%
# shoe shop, shoe-shop, shoe store: 8.8565%
# grocery store, grocery, food market, market: 5.1370%
# library: 4.6325%
#  15%|█▌        | 169/1102 [00:22<02:01,  7.69it/s]
# Top-5 Predictions for the video id:  0168_7-9-2-6804993792
# croquet ball: 34.0404%
# Irish wolfhound: 8.3143%
# ballplayer, baseball player: 7.5028%
# Saluki, gazelle hound: 6.4789%
# baseball: 4.2976%
#
# Top-5 Predictions for the video id:  0169_7-9-4-13012552794
# dugong, Dugong dugon: 19.8289%
# hammerhead, hammerhead shark: 17.5900%
# electric ray, crampfish, numbfish, torpedo: 5.9932%
# tiger shark, Galeocerdo cuvieri: 5.8871%
# sea snake: 5.5657%
#  16%|█▌        | 171/1102 [00:22<01:56,  8.00it/s]
# Top-5 Predictions for the video id:  0170_75FvTr78rVo_238
# pinwheel: 11.0753%
# piggy bank, penny bank: 10.9671%
# whistle: 9.1593%
# toaster: 8.5444%
# rubber eraser, rubber, pencil eraser: 6.9844%
#
# Top-5 Predictions for the video id:  0171_8-1-0-2784666810
# trimaran: 75.4766%
# catamaran: 22.4948%
# yawl: 0.5665%
# schooner: 0.3017%
# aircraft carrier, carrier, flattop, attack aircraft carrier: 0.2547%
#  16%|█▌        | 172/1102 [00:23<01:58,  7.85it/s]
# Top-5 Predictions for the video id:  0172_8-3-1-7-3-3-2-6-3583173326_54
# stretcher: 12.9885%
# golfcart, golf cart: 11.8857%
# punching bag, punch bag, punching ball, punchball: 5.3317%
# balance beam, beam: 5.1536%
# gong, tam-tam: 3.9901%
#
# Top-5 Predictions for the video id:  0173_8-5-6-13941149856
# Appenzeller: 11.4869%
# standard schnauzer: 7.8895%
# Saluki, gazelle hound: 7.7039%
# Border collie: 7.4326%
# Cardigan, Cardigan Welsh corgi: 4.5379%
#  16%|█▌        | 175/1102 [00:23<01:59,  7.77it/s]
# Top-5 Predictions for the video id:  0174_8-6-1-3575610861
# tricycle, trike, velocipede: 10.4469%
# neck brace: 5.5255%
# maraca: 5.4621%
# swab, swob, mop: 4.4126%
# pay-phone, pay-station: 4.0888%
#
# Top-5 Predictions for the video id:  0175_8-6-7-3034848867
# hair spray: 5.3185%
# Indian cobra, Naja naja: 3.1188%
# punching bag, punch bag, punching ball, punchball: 2.9461%
# cowboy boot: 2.4455%
# oxygen mask: 2.2501%
#  16%|█▌        | 177/1102 [00:23<01:58,  7.84it/s]
# Top-5 Predictions for the video id:  0176_8-7-1-7072478871
# parallel bars, bars: 10.1814%
# balance beam, beam: 9.6144%
# swimming trunks, bathing trunks: 8.8729%
# library: 7.9024%
# sarong: 5.1767%
#
# Top-5 Predictions for the video id:  0177_8-7-5-4-7-4-9-9-6687547499
# neck brace: 17.6028%
# maraca: 15.4337%
# balance beam, beam: 5.5446%
# hair spray: 4.8215%
# pajama, pyjama, pj's, jammies: 3.4237%
#  16%|█▌        | 178/1102 [00:23<02:02,  7.57it/s]
# Top-5 Predictions for the video id:  0178_8-7-8-2585165878
# grocery store, grocery, food market, market: 48.4252%
# shopping basket: 12.0676%
# library: 8.3209%
# toyshop: 5.5224%
# tobacco shop, tobacconist shop, tobacconist: 5.3535%
#
# Top-5 Predictions for the video id:  0179_8-7-8-4802252878
# tricycle, trike, velocipede: 89.8511%
# lawn mower, mower: 4.3397%
# swing: 3.4272%
# croquet ball: 0.5228%
# soccer ball: 0.5060%
#  16%|█▋        | 180/1102 [00:24<02:03,  7.44it/s]
# Top-5 Predictions for the video id:  0180_8-8-1-8014192881
# comic book: 27.9558%
# swimming trunks, bathing trunks: 13.0896%
# snorkel: 9.0374%
# stretcher: 8.4207%
# whistle: 3.3265%
#
# Top-5 Predictions for the video id:  0181_8-9-0-3381035890
# parallel bars, bars: 17.3785%
# library: 14.2378%
# bannister, banister, balustrade, balusters, handrail: 6.4617%
# bullet train, bullet: 5.8277%
# cradle: 3.1450%
#  17%|█▋        | 183/1102 [00:24<02:00,  7.60it/s]
# Top-5 Predictions for the video id:  0182_8-9-7-3822181897
# golfcart, golf cart: 11.2939%
# dumbbell: 10.2412%
# neck brace: 8.9992%
# maillot, tank suit: 8.0517%
# brassiere, bra, bandeau: 4.0472%
#
# Top-5 Predictions for the video id:  0183_8709292427
# potter's wheel: 18.3261%
# oxygen mask: 8.0021%
# library: 7.6853%
# nipple: 5.7492%
# candle, taper, wax light: 5.1869%
#  17%|█▋        | 185/1102 [00:24<01:57,  7.79it/s]
# Top-5 Predictions for the video id:  0184_8bbL5ZTo8J4_322
# spaghetti squash: 14.1190%
# space bar: 12.3376%
# conch: 8.4229%
# ear, spike, capitulum: 4.7803%
# typewriter keyboard: 3.3226%
#
# Top-5 Predictions for the video id:  0185_9-0-0-5-1-3-8-3-14090051383
# geyser: 98.3247%
# volcano: 1.4351%
# seashore, coast, seacoast, sea-coast: 0.0726%
# alp: 0.0126%
# lakeside, lakeshore: 0.0106%
#  17%|█▋        | 186/1102 [00:24<01:57,  7.78it/s]
# Top-5 Predictions for the video id:  0186_9-0-3-0-6-1-0-2-16890306102
# canoe: 27.6843%
# maypole: 22.8382%
# paddle, boat paddle: 20.8219%
# volleyball: 3.5973%
# go-kart: 1.8320%
#
# Top-5 Predictions for the video id:  0187_9-1-4-8-0-4-3-2-4391480432
# library: 18.2764%
# tobacco shop, tobacconist shop, tobacconist: 16.4179%
# toyshop: 15.9807%
# grocery store, grocery, food market, market: 10.1144%
# stretcher: 2.9129%
#  17%|█▋        | 189/1102 [00:25<01:54,  7.94it/s]
# Top-5 Predictions for the video id:  0188_9-1-6-3-6-9-9-7-4791636997
# scuba diver: 60.6567%
# snorkel: 14.4379%
# dugong, Dugong dugon: 6.3567%
# great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias: 2.8810%
# tiger shark, Galeocerdo cuvieri: 2.5979%
#
# Top-5 Predictions for the video id:  0189_9-3-3-3-4-8-5-2-3193334852
# geyser: 98.4016%
# breakwater, groin, groyne, mole, bulwark, seawall, jetty: 0.6568%
# volcano: 0.3640%
# seashore, coast, seacoast, sea-coast: 0.1681%
# fountain: 0.0543%
#  17%|█▋        | 190/1102 [00:25<01:57,  7.75it/s]
# Top-5 Predictions for the video id:  0190_9-3-6-5336600936
# shovel: 46.1954%
# ski: 17.4532%
# snorkel: 5.0102%
# catamaran: 1.9128%
# scuba diver: 1.8703%
#  17%|█▋        | 191/1102 [00:25<03:00,  5.04it/s]
# Top-5 Predictions for the video id:  0191_9-3-7-9-4-7-7-2-15393794772
# scuba diver: 39.7941%
# hammerhead, hammerhead shark: 15.2200%
# jellyfish: 11.6735%
# dugong, Dugong dugon: 7.3942%
# coral reef: 4.8706%
#
# Top-5 Predictions for the video id:  0192_9-4-9-8061428949
# ballplayer, baseball player: 11.1755%
# feather boa, boa: 8.4837%
# axolotl, mud puppy, Ambystoma mexicanum: 6.1439%
# standard poodle: 3.5549%
# swimming trunks, bathing trunks: 2.8037%
#  18%|█▊        | 193/1102 [00:26<02:28,  6.13it/s]
# Top-5 Predictions for the video id:  0193_9-5-5-4087587955
# balance beam, beam: 13.6576%
# potter's wheel: 13.4578%
# dumbbell: 4.5288%
# paddle, boat paddle: 3.2628%
# hair spray: 2.9689%
#
# Top-5 Predictions for the video id:  0194_9-6-0-4-3-8-6-5-17196043865
# library: 17.4376%
# barbell: 16.2364%
# Kerry blue terrier: 11.7006%
# dumbbell: 7.9798%
# parallel bars, bars: 5.3043%
#  18%|█▊        | 196/1102 [00:26<02:08,  7.07it/s]
# Top-5 Predictions for the video id:  0195_9-8-1-5713854981
# punching bag, punch bag, punching ball, punchball: 18.9480%
# bobsled, bobsleigh, bob: 9.1251%
# balloon: 7.8823%
# toyshop: 3.3718%
# maraca: 3.3006%
#
# Top-5 Predictions for the video id:  0196_9-8-8-3-3-0-9-9-3998833099
# bobsled, bobsleigh, bob: 8.1257%
# library: 7.6868%
# academic gown, academic robe, judge's robe: 7.5247%
# barbershop: 7.0344%
# hand-held computer, hand-held microcomputer: 5.0914%
#  18%|█▊        | 197/1102 [00:26<02:02,  7.36it/s]
# Top-5 Predictions for the video id:  0197_C_T0k4u1WVA_6
# pool table, billiard table, snooker table: 15.2407%
# punching bag, punch bag, punching ball, punchball: 4.9491%
# television, television system: 4.6161%
# Mexican hairless: 3.9117%
# power drill: 3.8516%
#
# Top-5 Predictions for the video id:  0198_HK42zQTEb1g_232
# stage: 53.3898%
# bassoon: 7.9255%
# trombone: 6.0386%
# drumstick: 4.7363%
# cornet, horn, trumpet, trump: 4.1270%
#  18%|█▊        | 199/1102 [00:26<02:00,  7.47it/s]
# Top-5 Predictions for the video id:  0199_KrKLuEmzcBM_26
# hamper: 11.8482%
# quilt, comforter, comfort, puff: 9.9667%
# Chihuahua: 7.1406%
# trifle: 4.7081%
# bassinet: 3.9831%
#
# Top-5 Predictions for the video id:  0200_L0axrvyv6co_40
# dumbbell: 47.5922%
# barbell: 5.0760%
# Mexican hairless: 4.0554%
# punching bag, punch bag, punching ball, punchball: 3.5524%
# neck brace: 2.6581%
#  18%|█▊        | 201/1102 [00:27<01:56,  7.71it/s]
# Top-5 Predictions for the video id:  0201_LnIGqQ6uIls_28
# cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM: 32.3337%
# barbell: 19.1885%
# ping-pong ball: 10.2886%
# web site, website, internet site, site: 6.5289%
# moving van: 2.6951%
#
# Top-5 Predictions for the video id:  0202_OeYnX9NwB1k_7
# beagle: 72.4475%
# basset, basset hound: 9.3562%
# Blenheim spaniel: 2.6224%
# Brittany spaniel: 2.2318%
# boxer: 1.5587%
#  18%|█▊        | 203/1102 [00:27<02:00,  7.45it/s]
# ...
# cleaver, meat cleaver, chopper: 3.4451%
# American lobster, Northern lobster, Maine lobster, Homarus americanus: 3.1708%
#  94%|█████████▍| 1040/1102 [02:26<00:09,  6.89it/s]
# Top-5 Predictions for the video id:  1040_flickr-2-8-2-9-2-9-1-2-5528292912_5
# Great Dane: 45.9119%
# curly-coated retriever: 17.5865%
# Scottish deerhound, deerhound: 7.6134%
# Doberman, Doberman pinscher: 7.2659%
# Saluki, gazelle hound: 2.7926%
#
# Top-5 Predictions for the video id:  1041_flickr-3-0-8-3-3-8-7-0-21830833870_4
# ballplayer, baseball player: 68.9779%
# baseball: 12.3185%
# scoreboard: 10.9808%
# basketball: 3.4797%
# volleyball: 0.6860%
#  95%|█████████▍| 1042/1102 [02:26<00:08,  6.85it/s]
# Top-5 Predictions for the video id:  1042_flickr-3-1-6-4273893316_10
# basketball: 90.0632%
# volleyball: 9.1969%
# unicycle, monocycle: 0.3254%
# knee pad: 0.1345%
# balance beam, beam: 0.0632%
#
# Top-5 Predictions for the video id:  1043_flickr-3-3-5-7-3-2-0-1-25133573201_2
# kite: 19.0975%
# bald eagle, American eagle, Haliaeetus leucocephalus: 12.4885%
# capuchin, ringtail, Cebus capucinus: 11.7022%
# gibbon, Hylobates lar: 8.7635%
# American black bear, black bear, Ursus americanus, Euarctos americanus: 6.0863%
#  95%|█████████▍| 1044/1102 [02:27<00:08,  6.77it/s]
# Top-5 Predictions for the video id:  1044_flickr-3-6-4-1-2-5-7-1-14436412571_16
# bloodhound, sleuthhound: 29.2242%
# basset, basset hound: 24.0345%
# redbone: 11.8786%
# Labrador retriever: 11.4115%
# English foxhound: 7.1000%
#
# Top-5 Predictions for the video id:  1045_flickr-3-9-0-1-2-9-0-4-5139012904_4
# mountain bike, all-terrain bike, off-roader: 34.0664%
# cliff, drop, drop-off: 15.7204%
# mountain tent: 3.7811%
# jeep, landrover: 3.7533%
# plow, plough: 2.2278%
#  95%|█████████▍| 1046/1102 [02:27<00:08,  6.77it/s]
# Top-5 Predictions for the video id:  1046_flickr-3-9-9-6-5-2-2-2-2839965222_1
# sea lion: 9.0420%
# red-breasted merganser, Mergus serrator: 7.9386%
# grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus: 6.3174%
# killer whale, killer, orca, grampus, sea wolf, Orcinus orca: 5.2329%
# otter: 3.1316%
#
# Top-5 Predictions for the video id:  1047_flickr-4-0-9-6-4-2-5-5-3740964255_17
# bathing cap, swimming cap: 32.9044%
# maillot, tank suit: 22.7844%
# swimming trunks, bathing trunks: 7.3714%
# bikini, two-piece: 7.3010%
# maillot: 4.6793%
#  95%|█████████▌| 1048/1102 [02:27<00:08,  6.60it/s]
# Top-5 Predictions for the video id:  1048_flickr-4-1-6-8-4-4-3-7-9241684437_1
# toyshop: 36.1139%
# barbershop: 2.9725%
# library: 2.2078%
# cowboy boot: 2.1271%
# confectionery, confectionary, candy store: 2.0413%
#
# Top-5 Predictions for the video id:  1049_flickr-4-2-3-3-7-5-1-1-5742337511_79
# swing: 33.4663%
# unicycle, monocycle: 18.9101%
# maypole: 14.4700%
# crutch: 5.8451%
# pole: 3.7576%
#  95%|█████████▌| 1050/1102 [02:28<00:07,  6.85it/s]
# Top-5 Predictions for the video id:  1050_flickr-4-3-8-2-7-2-5-3-24043827253_16
# shower cap: 15.6734%
# bow tie, bow-tie, bowtie: 7.7939%
# pajama, pyjama, pj's, jammies: 5.4425%
# kimono: 3.6752%
# mask: 2.7533%
#
# Top-5 Predictions for the video id:  1051_flickr-4-4-3-4-8-8-0-7-5544348807_2
# Doberman, Doberman pinscher: 10.4642%
# gar, garfish, garpike, billfish, Lepisosteus osseus: 6.1364%
# Greater Swiss Mountain dog: 5.0174%
# bloodhound, sleuthhound: 4.5722%
# cowboy boot: 3.4382%
#  95%|█████████▌| 1052/1102 [02:28<00:07,  6.53it/s]
# Top-5 Predictions for the video id:  1052_flickr-4-4-4-6-0-1-7-6-2844460176_19
# bassoon: 7.8757%
# pool table, billiard table, snooker table: 4.6854%
# jinrikisha, ricksha, rickshaw: 4.2318%
# steel drum: 3.6375%
# accordion, piano accordion, squeeze box: 3.1717%
#
# Top-5 Predictions for the video id:  1053_flickr-4-4-6-0-7-0-7-4-18344607074_27
# sarong: 18.5476%
# hoopskirt, crinoline: 18.3960%
# gown: 9.8369%
# miniskirt, mini: 4.3209%
# pajama, pyjama, pj's, jammies: 3.4563%
#  96%|█████████▌| 1054/1102 [02:28<00:07,  6.73it/s]
# Top-5 Predictions for the video id:  1054_flickr-4-5-1-3-9-3-3-5-4045139335_26
# coral reef: 31.5675%
# scuba diver: 14.9148%
# wreck: 11.8067%
# loggerhead, loggerhead turtle, Caretta caretta: 8.5915%
# brain coral: 6.4274%
#
# Top-5 Predictions for the video id:  1055_flickr-4-6-1-1-4-8-4-5-5646114845_3
# American lobster, Northern lobster, Maine lobster, Homarus americanus: 43.3597%
# Dungeness crab, Cancer magister: 12.0485%
# king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica: 9.0514%
# rotisserie: 8.4999%
# Dutch oven: 6.2460%
#  96%|█████████▌| 1056/1102 [02:28<00:06,  6.97it/s]
# Top-5 Predictions for the video id:  1056_flickr-4-6-2-0-0-8-2-0-7346200820_3
# miniskirt, mini: 9.5792%
# jean, blue jean, denim: 6.7336%
# croquet ball: 5.8587%
# hammer: 4.6322%
# crutch: 2.4514%
#
# Top-5 Predictions for the video id:  1057_flickr-4-6-3-6-6-6-1-8-5346366618_25
# African chameleon, Chamaeleo chamaeleon: 34.0965%
# green snake, grass snake: 28.6298%
# green mamba: 11.2236%
# vine snake: 3.5050%
# mantis, mantid: 2.4262%
#  96%|█████████▌| 1058/1102 [02:29<00:06,  6.78it/s]
# Top-5 Predictions for the video id:  1058_flickr-4-6-5-3-9-2-9-2-8446539292_1
# tub, vat: 15.4462%
# bikini, two-piece: 11.7062%
# bathing cap, swimming cap: 10.9686%
# bucket, pail: 10.5770%
# diaper, nappy, napkin: 7.7688%
#
# Top-5 Predictions for the video id:  1059_flickr-4-7-6-4-2-0-1-9-3147642019_44
# nipple: 9.2681%
# pajama, pyjama, pj's, jammies: 7.9005%
# oxygen mask: 4.3479%
# sunscreen, sunblock, sun blocker: 4.1685%
# Band Aid: 4.0552%
#  96%|█████████▌| 1060/1102 [02:29<00:06,  6.76it/s]
# Top-5 Predictions for the video id:  1060_flickr-5-1-1-3-0-6-1-1-5751130611_19
# unicycle, monocycle: 28.4072%
# Great Dane: 8.8219%
# broom: 6.7533%
# suit, suit of clothes: 2.9552%
# Staffordshire bullterrier, Staffordshire bull terrier: 2.7368%
#
# Top-5 Predictions for the video id:  1061_flickr-5-3-2-3-9-9-4-9-6553239949_6
# ski: 85.1934%
# alp: 10.2720%
# snowmobile: 2.5013%
# dogsled, dog sled, dog sleigh: 0.7975%
# snowplow, snowplough: 0.1937%
#  96%|█████████▋| 1062/1102 [02:29<00:05,  6.92it/s]
# Top-5 Predictions for the video id:  1062_flickr-5-5-5-2-7-6-7-5-6555527675_63
# whippet: 63.4620%
# pug, pug-dog: 12.6403%
# Siamese cat, Siamese: 3.1175%
# Sealyham terrier, Sealyham: 2.9818%
# Saint Bernard, St Bernard: 2.0700%
#
# Top-5 Predictions for the video id:  1063_flickr-5-6-5-9-6-6-9-8-4056596698_27
# desk: 22.5484%
# photocopier: 5.5519%
# sewing machine: 5.5162%
# file, file cabinet, filing cabinet: 4.7461%
# crib, cot: 4.4076%
#  97%|█████████▋| 1064/1102 [02:30<00:05,  6.81it/s]
# Top-5 Predictions for the video id:  1064_flickr-5-8-9-4-3-4-9-1-21858943491_22
# Chihuahua: 5.4040%
# Brabancon griffon: 4.5371%
# miniature pinscher: 4.1656%
# redbone: 3.7817%
# oxygen mask: 3.6477%
#
# Top-5 Predictions for the video id:  1065_flickr-5-9-5-4-5-3-9-6-23759545396_1
# Newfoundland, Newfoundland dog: 8.4537%
# amphibian, amphibious vehicle: 6.7827%
# water buffalo, water ox, Asiatic buffalo, Bubalus bubalis: 4.3249%
# ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus: 4.2698%
# flat-coated retriever: 3.4000%
#  97%|█████████▋| 1066/1102 [02:30<00:05,  6.60it/s]
# Top-5 Predictions for the video id:  1066_flickr-6-0-4-10248141604_15
# parachute, chute: 20.9407%
# lawn mower, mower: 9.9494%
# ballplayer, baseball player: 8.9061%
# racket, racquet: 5.0120%
# tennis ball: 3.4036%
#
# Top-5 Predictions for the video id:  1067_flickr-6-2-3-8-5-3-2-8-6262385328_12
# oxygen mask: 53.6280%
# Labrador retriever: 3.7366%
# French bulldog: 2.8687%
# beaker: 2.7850%
# muzzle: 2.4501%
#  97%|█████████▋| 1068/1102 [02:30<00:04,  6.89it/s]
# Top-5 Predictions for the video id:  1068_flickr-6-3-0-2-0-5-4-6-6163020546_34
# CD player: 6.6681%
# photocopier: 6.0565%
# scale, weighing machine: 4.8647%
# potter's wheel: 4.8113%
# cassette player: 3.3367%
#
# Top-5 Predictions for the video id:  1069_flickr-6-3-4-6-5-3-2-6-8663465326_1
# hot pot, hotpot: 59.1673%
# Crock Pot: 22.5186%
# frying pan, frypan, skillet: 9.1132%
# wok: 3.5246%
# Dutch oven: 1.6508%
#  97%|█████████▋| 1070/1102 [02:31<00:04,  7.04it/s]
# Top-5 Predictions for the video id:  1070_flickr-6-4-3-4-1-8-0-7-3564341807_2
# dogsled, dog sled, dog sleigh: 10.5325%
# snowmobile: 8.5617%
# ski: 6.8455%
# Chesapeake Bay retriever: 4.7585%
# Siberian husky: 3.3496%
#
# Top-5 Predictions for the video id:  1071_flickr-6-4-5-9-0-9-2-5-11864590925_1
# swing: 10.6862%
# bow: 9.1756%
# horizontal bar, high bar: 7.3130%
# rifle: 6.0761%
# balance beam, beam: 4.7815%
#  97%|█████████▋| 1072/1102 [02:31<00:04,  7.05it/s]
# Top-5 Predictions for the video id:  1072_flickr-6-5-7-1-6-0-5-3-4465716053_21
# bobsled, bobsleigh, bob: 8.6088%
# neck brace: 4.8611%
# seat belt, seatbelt: 3.8812%
# laptop, laptop computer: 3.6478%
# rain barrel: 2.6893%
#
# Top-5 Predictions for the video id:  1073_flickr-6-6-4-8-3-7-6-7-14766483767_4
# bubble: 27.4465%
# bathing cap, swimming cap: 9.6148%
# shower cap: 5.0808%
# gasmask, respirator, gas helmet: 4.8828%
# ski: 3.8251%
#  97%|█████████▋| 1074/1102 [02:31<00:03,  7.09it/s]
# Top-5 Predictions for the video id:  1074_flickr-6-6-6-3-3-6-2-9-3366633629_3
# ice lolly, lolly, lollipop, popsicle: 20.0317%
# seat belt, seatbelt: 15.0337%
# swing: 13.3238%
# quill, quill pen: 2.3496%
# horizontal bar, high bar: 2.0729%
#
# Top-5 Predictions for the video id:  1075_flickr-7-0-6-11866890706_21
# bannister, banister, balustrade, balusters, handrail: 90.1079%
# guillotine: 0.7545%
# vacuum, vacuum cleaner: 0.6796%
# crutch: 0.4057%
# streetcar, tram, tramcar, trolley, trolley car: 0.3090%
#  98%|█████████▊| 1076/1102 [02:31<00:03,  7.12it/s]
# Top-5 Predictions for the video id:  1076_flickr-7-0-6-9-5-0-6-9-4870695069_7
# harp: 17.0906%
# broom: 12.9230%
# maypole: 10.5398%
# Sussex spaniel: 6.9682%
# Afghan hound, Afghan: 6.7237%
#
# Top-5 Predictions for the video id:  1077_flickr-7-0-8-7-2-3-0-0-4670872300_21
# Labrador retriever: 11.8894%
# bluetick: 10.5407%
# Great Dane: 9.3461%
# bull mastiff: 6.4807%
# German short-haired pointer: 5.5856%
#  98%|█████████▊| 1078/1102 [02:32<00:03,  6.92it/s]
# Top-5 Predictions for the video id:  1078_flickr-7-1-2-0-7-9-8-2-15371207982_57
# snorkel: 70.3111%
# swimming trunks, bathing trunks: 8.2421%
# bathing cap, swimming cap: 3.9190%
# stingray: 3.8081%
# bikini, two-piece: 3.1738%
#
# Top-5 Predictions for the video id:  1079_flickr-7-2-5-4-8-0-1-2-3572548012_36
# swing: 4.7957%
# guillotine: 4.7114%
# bannister, banister, balustrade, balusters, handrail: 4.4616%
# sliding door: 3.7090%
# rocking chair, rocker: 3.6033%
#  98%|█████████▊| 1080/1102 [02:32<00:04,  5.16it/s]
# Top-5 Predictions for the video id:  1080_flickr-7-4-6-0-0-0-8-5-6074600085_35
# bathtub, bathing tub, bath, tub: 17.4887%
# diaper, nappy, napkin: 15.8876%
# tub, vat: 9.4156%
# potter's wheel: 6.3097%
# soap dispenser: 4.4100%
#
# Top-5 Predictions for the video id:  1081_flickr-7-4-6-7-0-5-2-2-2874670522_7
# hay: 19.9960%
# plow, plough: 15.7032%
# cannon: 4.3908%
# horse cart, horse-cart: 4.2519%
# barrow, garden cart, lawn cart, wheelbarrow: 4.0757%
#  98%|█████████▊| 1082/1102 [02:32<00:03,  6.00it/s]
# Top-5 Predictions for the video id:  1082_flickr-7-5-9-2-7-9-5-7-5075927957_19
# tricycle, trike, velocipede: 12.1930%
# apron: 10.0601%
# parallel bars, bars: 6.9265%
# plunger, plumber's helper: 5.3321%
# paddle, boat paddle: 5.1942%
#
# Top-5 Predictions for the video id:  1083_flickr-7-7-3-9603898773_34
# geyser: 21.9052%
# valley, vale: 13.4304%
# promontory, headland, head, foreland: 4.5774%
# cliff, drop, drop-off: 4.2357%
# borzoi, Russian wolfhound: 2.8855%
#  98%|█████████▊| 1084/1102 [02:33<00:02,  6.63it/s]
# Top-5 Predictions for the video id:  1084_flickr-7-9-1-9-7-8-4-1-5979197841_5
# sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita: 67.0706%
# weasel: 7.5500%
# ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus: 5.1309%
# kite: 2.9071%
# Sealyham terrier, Sealyham: 2.4862%
#
# Top-5 Predictions for the video id:  1085_flickr-7-9-4-0-2-6-4-0-6079402640_3
# hog, pig, grunter, squealer, Sus scrofa: 17.2657%
# wild boar, boar, Sus scrofa: 5.1448%
# black-footed ferret, ferret, Mustela nigripes: 4.7433%
# sea lion: 4.4903%
# goose: 3.7387%
#  99%|█████████▊| 1086/1102 [02:33<00:02,  6.82it/s]
# Top-5 Predictions for the video id:  1086_flickr-7-9-4-4-0-1-3-1-4879440131_23
# porcupine, hedgehog: 93.7442%
# echidna, spiny anteater, anteater: 0.9531%
# puffer, pufferfish, blowfish, globefish: 0.6689%
# ping-pong ball: 0.3194%
# axolotl, mud puppy, Ambystoma mexicanum: 0.2794%
#
# Top-5 Predictions for the video id:  1087_flickr-8-3-0-8-9-8-8-1-6683089881_3
# crib, cot: 78.2865%
# cradle: 12.9170%
# panpipe, pandean pipe, syrinx: 2.9498%
# plate rack: 1.0994%
# prison, prison house: 0.7908%
#  99%|█████████▊| 1088/1102 [02:33<00:02,  6.92it/s]
# Top-5 Predictions for the video id:  1088_flickr-8-5-6-1-4-4-5-2-4385614452_26
# parallel bars, bars: 26.7894%
# maze, labyrinth: 7.9194%
# horizontal bar, high bar: 7.8085%
# balance beam, beam: 6.5430%
# dumbbell: 2.1897%
#
# Top-5 Predictions for the video id:  1089_flickr-8-7-6-1-4-7-8-2-4287614782_43
# balance beam, beam: 41.2278%
# projector: 5.1307%
# parallel bars, bars: 3.9692%
# marimba, xylophone: 3.9537%
# bobsled, bobsleigh, bob: 3.7044%
#  99%|█████████▉| 1090/1102 [02:34<00:01,  6.86it/s]
# Top-5 Predictions for the video id:  1090_flickr-8-7-8-9-2-2-1-8-17787892218_4
# stage: 5.1030%
# knee pad: 3.4745%
# unicycle, monocycle: 2.6297%
# torch: 2.4718%
# harmonica, mouth organ, harp, mouth harp: 2.1701%
#
# Top-5 Predictions for the video id:  1091_flickr-8-9-1-1-1-8-9-7-6289111897_52
# sorrel: 78.8969%
# Arabian camel, dromedary, Camelus dromedarius: 10.6543%
# Rhodesian ridgeback: 2.8839%
# swimming trunks, bathing trunks: 2.2260%
# vizsla, Hungarian pointer: 1.3759%
#  99%|█████████▉| 1092/1102 [02:34<00:01,  6.75it/s]
# Top-5 Predictions for the video id:  1092_flickr-8-9-2-5207705892_5
# balloon: 17.4809%
# parachute, chute: 11.5061%
# pinwheel: 8.2146%
# toyshop: 6.6844%
# ant, emmet, pismire: 3.3632%
#
# Top-5 Predictions for the video id:  1093_flickr-9-1-1-6-2-7-4-0-8691162740_7
# ice cream, icecream: 6.6974%
# teapot: 6.2027%
# nipple: 4.8330%
# piggy bank, penny bank: 3.3890%
# candle, taper, wax light: 3.0559%
#  99%|█████████▉| 1094/1102 [02:34<00:01,  6.50it/s]
# Top-5 Predictions for the video id:  1094_flickr-9-2-6-2-1-2-9-5-6292621295_19
# tub, vat: 14.8907%
# bathtub, bathing tub, bath, tub: 10.1738%
# swimming trunks, bathing trunks: 8.4524%
# ice lolly, lolly, lollipop, popsicle: 8.4125%
# bikini, two-piece: 4.7563%
#
# Top-5 Predictions for the video id:  1095_flickr-9-2-7-0-8-0-7-0-4292708070_55
# four-poster: 36.0891%
# balance beam, beam: 14.6551%
# parallel bars, bars: 14.3383%
# mosquito net: 9.0624%
# barbell: 2.4591%
#  99%|█████████▉| 1096/1102 [02:34<00:00,  6.94it/s]
# Top-5 Predictions for the video id:  1096_flickr-9-7-8-9-1-2-7-1-3797891271_19
# iron, smoothing iron: 25.2929%
# ladle: 7.4809%
# paintbrush: 5.0676%
# sandal: 4.8367%
# spatula: 4.3399%
#
# Top-5 Predictions for the video id:  1097_flickr-9-7-9-2-2-7-7-2-25797922772_10
# kite: 12.0825%
# black-and-tan coonhound: 9.2486%
# Rottweiler: 8.9311%
# German shepherd, German shepherd dog, German police dog, alsatian: 7.4254%
# robin, American robin, Turdus migratorius: 7.3763%
# 100%|█████████▉| 1098/1102 [02:35<00:00,  6.98it/s]
# Top-5 Predictions for the video id:  1098_flickr-9-8-3-6-5-8-3-2-3798365832_1
# plate rack: 18.0937%
# bassinet: 16.9342%
# carton: 10.7630%
# mixing bowl: 10.4538%
# shower cap: 4.5684%
#
# Top-5 Predictions for the video id:  1099_flickr-9-9-3-9-3-3-1-0-6799393310_48
# speedboat: 58.3731%
# canoe: 19.6385%
# lifeboat: 6.0956%
# paddle, boat paddle: 5.0132%
# amphibian, amphibious vehicle: 1.9121%
# 100%|█████████▉| 1100/1102 [02:35<00:00,  7.06it/s]
# Top-5 Predictions for the video id:  1100_flickr-jena76-4855129978_5
# lab coat, laboratory coat: 32.5441%
# beaker: 9.9936%
# cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM: 5.5342%
# Windsor tie: 2.1939%
# dumbbell: 2.1594%
#
# Top-5 Predictions for the video id:  1101_flickr-scrambldmeggs-3606262338_21
# dam, dike, dyke: 53.6948%
# ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus: 4.3666%
# sandbar, sand bar: 3.4464%
# fountain: 2.6984%
# breakwater, groin, groyne, mole, bulwark, seawall, jetty: 2.6769%
# 100%|██████████| 1102/1102 [02:35<00:00,  7.08it/s]
# Top-5 Predictions for the video id:  1102_meta_R-5602303_250
# disk brake, disc brake: 25.8049%
# moped: 21.3319%
# motor scooter, scooter: 8.4989%
# horse cart, horse-cart: 7.1065%
# crash helmet: 5.6486%

# %%
# preprocessing using PCA and save
pca_dir = os.path.join(save_dir, 'pca_100')
print("-------------performing  PCA----------------------------")
do_PCA_and_save(activations_dir, pca_dir)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# -------------performing  PCA----------------------------
# 100%|██████████| 8/8 [00:33<00:00,  4.24s/it]

# %% [markdown]
# # Voxel Wise Encoding
#
# The approach has three steps:
#
# 1. Features of a computer vision model to videos are extracted (Fig. 1A). This changes the format of the data (from pixels to model features) and typically reduces the dimensionality of the data. The features of a given model are interpreted as a potential hypothesis about the features that a given brain area might be using to represent the stimulus.
# 2. Features of the computational model are linearly mapped onto each voxel's responses (Fig. 1B) using the training set provided. This step is necessary as there is not necessarily a one-to-one mapping between voxels and model features. Instead, each voxel's response is hypothesized to correspond to a weighted combination of activations of multiple features of the model.
# 3. The estimated mapping from the training dataset is applied on the model features corresponding to videos in the test set to predict synthetic brain data (Fig. 1C). The predicted synthetic brain data is then compared against the ground-truth left out brain data in the testing set.

# %% [markdown]
# ![Encoding-1.png](data:image/png;base64,...)

# %% [markdown]
# **Figure 1**: **A)** First, given the training set videos, the features of a computational model are extracted. **B)** A mapping between model features and brain voxels is estimated from the Training Set videos. **C)** A mapping between model features and brain voxels is generated on the test set videos, therefore, generating a predicted voxel v's activity for a given video.

# %% [markdown]
# ## Evaluation
#
# To determine how well a model predicts brain responses we compare synthetic brain data (i.e. those predicted from your model to the left out video clips) to the empirically measured brain responses. The comparison is carried out using Pearson's correlation, comparing for each voxel the 100-dimensional vector formed by the activations for the 100 validation set video clips.

# %% [markdown]
# ![Eval_colab.png](data:image/png;base64,...)

# %%
#@title Utility functions for regression
def vectorized_correlation(x,y):
    dim = 0

    centered_x = x - x.mean(axis=dim, keepdims=True)
    centered_y = y - y.mean(axis=dim, keepdims=True)

    covariance = (centered_x * centered_y).sum(axis=dim, keepdims=True)

    bessel_corrected_covariance = covariance / (x.shape[dim] - 1)

    x_std = x.std(axis=dim, keepdims=True)+1e-8
    y_std = y.std(axis=dim, keepdims=True)+1e-8

    corr = bessel_corrected_covariance / (x_std * y_std)

    return corr.ravel()

class OLS_pytorch(object):
    def __init__(self,use_gpu=False):
        self.coefficients = []
        self.use_gpu = use_gpu
        self.X = None
        self.y = None

    def fit(self,X,y):
        if len(X.shape) == 1:
            X = self._reshape_x(X)
        if len(y.shape) == 1:
            y = self._reshape_x(y)

        X =  self._concatenate_ones(X)

        X = torch.from_numpy(X).float()
        y = torch.from_numpy(y).float()
        if self.use_gpu:
            X = X.cuda()
            y = y.cuda()
        XtX = torch.matmul(X.t(),X)
        Xty = torch.matmul(X.t(),y.unsqueeze(2))
        XtX = XtX.unsqueeze(0)
        XtX = torch.repeat_interleave(XtX, y.shape[0], dim=0)
        betas_cholesky, _ = torch.solve(Xty, XtX)

        self.coefficients = betas_cholesky

    def predict(self, entry):
        if len(entry.shape) == 1:
            entry = self._reshape_x(entry)
        entry =  self._concatenate_ones(entry)
        entry = torch.from_numpy(entry).float()
        if self.use_gpu:
            entry = entry.cuda()
        prediction = torch.matmul(entry,self.coefficients)
        prediction = prediction.cpu().numpy()
        prediction = np.squeeze(prediction).T
        return prediction

    def _reshape_x(self,X):
        return X.reshape(-1,1)

    def _concatenate_ones(self,X):
        ones = np.ones(shape=X.shape[0]).reshape(-1,1)
        return np.concatenate((ones,X),1)

def predict_fmri_fast(train_activations, test_activations, train_fmri,use_gpu=False):
    """This function fits a linear regressor using train_activations and train_fmri,
    then returns the predicted fmri_pred_test using the fitted weights and
    test_activations.
    Parameters
    ----------
    train_activations : np.array
        matrix of dimensions #train_vids x #pca_components
        containing activations of train videos.
    test_activations : np.array
        matrix of dimensions #test_vids x #pca_components
        containing activations of test videos
    train_fmri : np.array
        matrix of dimensions #train_vids x  #voxels
        containing fMRI responses to train videos
    use_gpu : bool
        Description of parameter `use_gpu`.
    Returns
    -------
    fmri_pred_test: np.array
        matrix of dimensions #test_vids x  #voxels
        containing predicted fMRI responses to test videos .
    """

    reg = OLS_pytorch(use_gpu)
    reg.fit(train_activations,train_fmri.T)
    fmri_pred_test = reg.predict(test_activations)
    return fmri_pred_test

# %%
def perform_encoding(activation_dir, fmri_dir,results_dir, sub, layer, ROI = 'WB', mode = 'val', visualize_results = True\
                     , batch_size=1000):
  if torch.cuda.is_available():
      use_gpu = True
  else:
      use_gpu = False

  ###### Load activations ##############
  activations_dir = '/content/activations_alexnet'
  pca_dir = os.path.join(activations_dir,'pca_100')
  train_activations,test_activations = get_activations(pca_dir, layer)
  ######################################

  ##### Load fMRI data #################
  if ROI == "WB":
      track = "full_track"
  else:
      track = "mini_track"
  fmri_dir = os.path.join(fmri_dir, track)
  sub_fmri_dir = os.path.join(fmri_dir, sub)
  if track == "full_track":
      fmri_train_all,voxel_mask = get_fmri(sub_fmri_dir,ROI)
  else:
      fmri_train_all = get_fmri(sub_fmri_dir,ROI)
  num_voxels = fmri_train_all.shape[1]
  ######################################


  #### Creating data splits ###############
  if mode == 'val':
      # Here as an example we use first 900 videos as training and rest of the videos as validation
      test_activations = train_activations[900:,:]
      train_activations = train_activations[:900,:]
      fmri_train = fmri_train_all[:900,:]
      fmri_test = fmri_train_all[900:,:]
      pred_fmri = np.zeros_like(fmri_test)
      pred_fmri_save_path = os.path.join(results_dir, ROI + '_val.npy')
  else:
      fmri_train = fmri_train_all
      num_test_videos = 102
      pred_fmri = np.zeros((num_test_videos,num_voxels))
      pred_fmri_save_path = os.path.join(results_dir, ROI + '_test.npy')
  ######################################

  ######## Performing regression ################
  iter = 0
  
  while iter < num_voxels-batch_size:
      pred_fmri[:,iter:iter+batch_size] = predict_fmri_fast(train_activations,test_activations,fmri_train[:,iter:iter+batch_size], use_gpu = use_gpu)
      iter = iter+batch_size
  pred_fmri[:,iter:] = predict_fmri_fast(train_activations,test_activations,fmri_train[:,iter:iter+batch_size], use_gpu = use_gpu)
  if mode == 'val':
    score = vectorized_correlation(fmri_test,pred_fmri)
    print("----------------------------------------------------------------------------")
    print("Mean correlation for ROI : ",ROI, "in ",sub," using ",layer, " is :", round(score.mean(), 6))
    ################################################
    
    nii_save_path =  os.path.join(results_dir, ROI + '_val.nii')
    ######## Result visualization ################
    if track == "full_track" and visualize_results:
        visual_mask_3D = np.zeros((78,93,71))
        visual_mask_3D[voxel_mask==1]= score
        brain_mask = '/content/example.nii'
        saveasnii(brain_mask,nii_save_path,visual_mask_3D)
        plotting.plot_glass_brain(nii_save_path,plot_abs=False,
                          title='Correlation for ' + sub+ ' and ' + layer,
                          display_mode='lyr',colorbar=True,vmin=-1,vmax=1)

    ################################################

  np.save(pred_fmri_save_path, pred_fmri)

# %%
#@title Perform and evaluate encoding on validation set
sub = 'sub04'  #@param ["sub01","sub02","sub03","sub04","sub05","sub06","sub07","sub08","sub09","sub10"]  

ROI = 'EBA'  #@param ["WB", "V1", "V2","V3", "V4", "LOC", "EBA", "FFA","STS", "PPA"]

layer = 'layer_5' #@param ["layer_1","layer_2","layer_3","layer_4","layer_5","layer_6","layer_7","layer_8"]

fmri_dir = '/content/participants_data_v2021'
prediction_dir = '/content/prediction'
model = 'alexnet'

if ROI == "WB":
    track = "full_track"
else:
    track = "mini_track"

results_dir = os.path.join(prediction_dir,model, layer,\
                           track, sub)
if not os.path.exists(results_dir):
  os.makedirs(results_dir)
perform_encoding(activations_dir, fmri_dir,\
                                 results_dir, sub, layer, ROI=ROI)
# Out:
# ----------------------------------------------------------------------------
# Mean correlation for ROI :  EBA in  sub04  using  layer_5  is : 0.219405
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:760.)

# %% [markdown]
# If you use the default parameters (sub04, EBA, layer_5) you should obtain a correlation of 0.219 between predicted and recorded fMRI responses on validation videos.

# %% [markdown]
# # Predict fMRI responses to test videos for all subjects all ROIs
# Run the cell below to save predicted fMRI responses to test videos for all subjects and ROIs.

# %%
subs = ["sub01","sub02","sub03","sub04","sub05","sub06","sub07","sub08","sub09","sub10"]  
ROIs = ["WB", "V1", "V2","V3", "V4", "LOC", "EBA", "FFA","STS", "PPA"]
layer = 'layer_5'
model = 'alexnet'
for sub in subs:
  for ROI in ROIs:
    if ROI == "WB":
        track = "full_track"
    else:
        track = "mini_track"
    results_dir = os.path.join(prediction_dir,model, layer,\
                           track, sub)
    if not os.path.exists(results_dir):
      os.makedirs(results_dir)
    print ("Starting ROI: ", ROI, "sub: ",sub)
    perform_encoding(activations_dir, fmri_dir,\
                     results_dir, sub, layer,\
                     ROI=ROI,mode='test')
    print ("Completed ROI: ", ROI, "sub: ",sub)
    print("----------------------------------------------------------------------------")
# Out:
# Starting ROI:  WB sub:  sub01
# Completed ROI:  WB sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub01
# Completed ROI:  V1 sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub01
# Completed ROI:  V2 sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub01
# Completed ROI:  V3 sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub01
# Completed ROI:  V4 sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub01
# Completed ROI:  LOC sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub01
# Completed ROI:  EBA sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub01
# Completed ROI:  FFA sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub01
# Completed ROI:  STS sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub01
# Completed ROI:  PPA sub:  sub01
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub02
# Completed ROI:  WB sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub02
# Completed ROI:  V1 sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub02
# Completed ROI:  V2 sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub02
# Completed ROI:  V3 sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub02
# Completed ROI:  V4 sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub02
# Completed ROI:  LOC sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub02
# Completed ROI:  EBA sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub02
# Completed ROI:  FFA sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub02
# Completed ROI:  STS sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub02
# Completed ROI:  PPA sub:  sub02
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub03
# Completed ROI:  WB sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub03
# Completed ROI:  V1 sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub03
# Completed ROI:  V2 sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub03
# Completed ROI:  V3 sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub03
# Completed ROI:  V4 sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub03
# Completed ROI:  LOC sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub03
# Completed ROI:  EBA sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub03
# Completed ROI:  FFA sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub03
# Completed ROI:  STS sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub03
# Completed ROI:  PPA sub:  sub03
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub04
# Completed ROI:  WB sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub04
# Completed ROI:  V1 sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub04
# Completed ROI:  V2 sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub04
# Completed ROI:  V3 sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub04
# Completed ROI:  V4 sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub04
# Completed ROI:  LOC sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub04
# Completed ROI:  EBA sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub04
# Completed ROI:  FFA sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub04
# Completed ROI:  STS sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub04
# Completed ROI:  PPA sub:  sub04
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub05
# Completed ROI:  WB sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub05
# Completed ROI:  V1 sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub05
# Completed ROI:  V2 sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub05
# Completed ROI:  V3 sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub05
# Completed ROI:  V4 sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub05
# Completed ROI:  LOC sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub05
# Completed ROI:  EBA sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub05
# Completed ROI:  FFA sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub05
# Completed ROI:  STS sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub05
# Completed ROI:  PPA sub:  sub05
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub06
# Completed ROI:  WB sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub06
# Completed ROI:  V1 sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub06
# Completed ROI:  V2 sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub06
# Completed ROI:  V3 sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub06
# Completed ROI:  V4 sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub06
# Completed ROI:  LOC sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub06
# Completed ROI:  EBA sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub06
# Completed ROI:  FFA sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub06
# Completed ROI:  STS sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub06
# Completed ROI:  PPA sub:  sub06
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub07
# Completed ROI:  WB sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub07
# Completed ROI:  V1 sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub07
# Completed ROI:  V2 sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub07
# Completed ROI:  V3 sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub07
# Completed ROI:  V4 sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub07
# Completed ROI:  LOC sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub07
# Completed ROI:  EBA sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub07
# Completed ROI:  FFA sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub07
# Completed ROI:  STS sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub07
# Completed ROI:  PPA sub:  sub07
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub08
# Completed ROI:  WB sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub08
# Completed ROI:  V1 sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub08
# Completed ROI:  V2 sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub08
# Completed ROI:  V3 sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub08
# Completed ROI:  V4 sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub08
# Completed ROI:  LOC sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub08
# Completed ROI:  EBA sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub08
# Completed ROI:  FFA sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub08
# Completed ROI:  STS sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub08
# Completed ROI:  PPA sub:  sub08
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub09
# Completed ROI:  WB sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub09
# Completed ROI:  V1 sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub09
# Completed ROI:  V2 sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub09
# Completed ROI:  V3 sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub09
# Completed ROI:  V4 sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub09
# Completed ROI:  LOC sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub09
# Completed ROI:  EBA sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub09
# Completed ROI:  FFA sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub09
# Completed ROI:  STS sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub09
# Completed ROI:  PPA sub:  sub09
# ----------------------------------------------------------------------------
# Starting ROI:  WB sub:  sub10
# Completed ROI:  WB sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  V1 sub:  sub10
# Completed ROI:  V1 sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  V2 sub:  sub10
# Completed ROI:  V2 sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  V3 sub:  sub10
# Completed ROI:  V3 sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  V4 sub:  sub10
# Completed ROI:  V4 sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  LOC sub:  sub10
# Completed ROI:  LOC sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  EBA sub:  sub10
# Completed ROI:  EBA sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  FFA sub:  sub10
# Completed ROI:  FFA sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  STS sub:  sub10
# Completed ROI:  STS sub:  sub10
# ----------------------------------------------------------------------------
# Starting ROI:  PPA sub:  sub10
# Completed ROI:  PPA sub:  sub10
# ----------------------------------------------------------------------------

# %% [markdown]
# #Prepare submission files
#
# Now, we will prepare the zipfiles for submission to codalab. After running the two cells below you will see a Pickle and a zip file (containing the Pickle file) for the corresponding track in the colab file directory.
#
# Submit the mini_track results [here](https://competitions.codalab.org/competitions/30930#participate-submit_results) and full_track results [here](https://competitions.codalab.org/competitions/30937#participate-submit_results)

# %%
def prepare_results(submission_dir, track):
    if track == 'full_track':
        ROIs = ['WB']
    else:
        ROIs = ['LOC','FFA','STS','EBA','PPA','V1','V2','V3','V4']

    num_subs = 10
    subs=[]
    for s in range(num_subs):
        subs.append('sub'+str(s+1).zfill(2))

    results = {}
    for ROI in ROIs:
        ROI_results = {}
        for sub in subs:
            ROI_result_file = os.path.join(submission_dir,track,sub,ROI+"_test.npy")
            if not os.path.exists(ROI_result_file):
                print("---------Warning : submission not ready ----------")
                print("Result not found for ",sub, " and ROI: ",ROI)
                print("Result file path: ", ROI_result_file)
                print("Please check if the directory is correct or generate predicted data for ROI: ",ROI , " in subject: ", sub)
                return
            ROI_result = np.load(ROI_result_file)
            ROI_results[sub] = ROI_result
        results[ROI] = ROI_results

    save_dict(results,track+".pkl")
    zipped_results = zipfile.ZipFile(track+".zip", 'w')
    zipped_results.write(track+".pkl")
    zipped_results.close()

# %%
import zipfile
submission_dir = '/content/prediction/alexnet/layer_5'
prepare_results(submission_dir, 'full_track')
prepare_results(submission_dir, 'mini_track')

# %% [markdown]
# Click the folder button on the left panel and you should see zipfiles ready for submission

# %% [markdown]
# #Reference
#
# [The Algonauts Project 2021 Challenge: How the Human Brain Makes Sense of a World in Motion.
# *Cichy et al. arxiv 2021*](https://arxiv.org/abs/2104.13714v1)
